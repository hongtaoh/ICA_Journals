# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import altair as alt
from altair import datum

# %%
papers = pd.read_csv('../data/processed/papers_to_study_expanded.csv')
set(papers.journal)
# Out:
# {'Communication Theory',
#  'Communication, Culture and Critique',
#  'Human Communication Research',
#  'Journal of Communication',
#  'Journal of Computer-Mediated Communication'}

# %%
# joc
joc = papers[papers.journal == 'Journal of Communication'].sort_values(by="year", ascending= True)
joc.head(1)
# Out:
#                        journal  \
# 2625  Journal of Communication
#
#                                                issueURL    volumn    issue  \
# 2625  https://academic.oup.com/joc/issue/1/1?browseB...  Volume 1  Issue 1
#
#                           issueText month  year  category  \
# 2625  Issue 1, May 1951, Pages 1–72   May  1951  Articles
#
#                                  title  \
# 2625  University Courses on Television
#
#                                                     url  ...  \
# 2625  https://academic.oup.com/joc/article/1/1/66/46...  ...
#
#      cross_gender_race_and_country numberOfAuthors first_author_gender  \
# 2625                         False             2.0                   M
#
#       first_author_race first_author_country  first_author_afftype  \
# 2625              White                   US             Education
#
#       with_us_authors  cross_race_details  cross_gender_details  \
# 2625             True          White only                M only
#
#       gscholar_citation
# 2625                0.0
#
# [1 rows x 34 columns]

# %%
# ccc
ccc = papers[papers.journal == 'Communication, Culture and Critique'].sort_values(by="year", ascending= True)
ccc.head(1)
# Out:
#                                   journal  \
# 5711  Communication, Culture and Critique
#
#                                                issueURL    volumn    issue  \
# 5711  https://academic.oup.com/ccc/issue/1/1?browseB...  Volume 1  Issue 1
#
#                              issueText  month  year           category  \
# 5711  Issue 1, March 2008, Pages 1–142  March  2008  Original Articles
#
#                                           title  \
# 5711  The Militarization of U.S. Communications
#
#                                                     url  ...  \
# 5711  https://academic.oup.com/ccc/article/1/1/126/4...  ...
#
#      cross_gender_race_and_country numberOfAuthors first_author_gender  \
# 5711                         False             1.0                   M
#
#       first_author_race first_author_country  first_author_afftype  \
# 5711              White                   US             Education
#
#       with_us_authors  cross_race_details  cross_gender_details  \
# 5711             True          White only                M only
#
#       gscholar_citation
# 5711               52.0
#
# [1 rows x 34 columns]

# %%
ccc.shape
# Out:
# (459, 34)

# %%
hcr = papers[papers.journal == 'Human Communication Research'].sort_values(by="year", ascending= True)
hcr.head(1)
# Out:
#                            journal  \
# 3778  Human Communication Research
#
#                                                issueURL    volumn    issue  \
# 3778  https://academic.oup.com/hcr/issue/1/1?browseB...  Volume 1  Issue 1
#
#                                 issueText      month  year  category  \
# 3778  Issue 1, September 1974, Pages 3–91  September  1974  Articles
#
#                                                   title  \
# 3778  Communication and Conflict: A Review of New Ma...
#
#                                                     url  ...  \
# 3778  https://academic.oup.com/hcr/article/1/1/81/46...  ...
#
#      cross_gender_race_and_country numberOfAuthors first_author_gender  \
# 3778                         False             1.0                   M
#
#       first_author_race first_author_country  first_author_afftype  \
# 3778              White                   US             Education
#
#       with_us_authors  cross_race_details  cross_gender_details  \
# 3778             True          White only                M only
#
#       gscholar_citation
# 3778                8.0
#
# [1 rows x 34 columns]

# %%
jcmc = papers[papers.journal == 'Journal of Computer-Mediated Communication'].sort_values(by="year", ascending= True)
jcmc.head(1)
# Out:
#                                          journal  \
# 5252  Journal of Computer-Mediated Communication
#
#                                                issueURL    volumn    issue  \
# 5252  https://academic.oup.com/jcmc/issue/1/1?browse...  Volume 1  Issue 1
#
#                  issueText month  year          category  \
# 5252  Issue 1, 1 June 1995  June  1995  Original Article
#
#                                                   title  \
# 5252  The ‘Icp OnLine’: Jeux sans frontières on the ...
#
#                                                     url  ...  \
# 5252  https://academic.oup.com/jcmc/article/1/1/JCMC...  ...
#
#      cross_gender_race_and_country numberOfAuthors first_author_gender  \
# 5252                         False             1.0                   M
#
#       first_author_race first_author_country  first_author_afftype  \
# 5252              White                   US             Education
#
#       with_us_authors  cross_race_details  cross_gender_details  \
# 5252             True          White only                M only
#
#       gscholar_citation
# 5252               20.0
#
# [1 rows x 34 columns]

# %%
ct = papers[papers.journal == 'Communication Theory'].sort_values(by="year", ascending= True)
ct.head(1)
# Out:
#                    journal                                           issueURL  \
# 4407  Communication Theory  https://academic.oup.com/ct/issue/1/1?browseBy...
#
#         volumn    issue                           issueText     month  year  \
# 4407  Volume 1  Issue 1  Issue 1, February 1991, Pages 1–86  February  1991
#
#                 category                                              title  \
# 4407  Comparative Theory  Comparative Theory Reconceptualized: From Enti...
#
#                                                     url  ...  \
# 4407  https://academic.oup.com/ct/article/1/1/59/443...  ...
#
#      cross_gender_race_and_country numberOfAuthors first_author_gender  \
# 4407                         False             1.0                   F
#
#       first_author_race first_author_country  first_author_afftype  \
# 4407              White                   US             Education
#
#       with_us_authors  cross_race_details  cross_gender_details  \
# 4407             True          White only                F only
#
#       gscholar_citation
# 4407              101.0
#
# [1 rows x 34 columns]
