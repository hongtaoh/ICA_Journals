# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import altair as alt
from altair import datum

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_simple_prop_df(data, var):
    # get frequency and proportion over all the years
    assert data in ['papers', 'authors'], 'data is wrong!'
    if data == 'authors':
        df = pd.DataFrame(Counter(authors[var]).items(), columns = [var, 'freq'])
        df['prop'] = round(df['freq'] / total_author_num, 3)
        df.sort_values('prop', ascending = False, inplace = True)
    else:
        df = pd.DataFrame(Counter(papers[var]).items(), columns = [var, 'freq'])
        df['prop'] = round(df['freq'] / total_paper_num, 3)
        df.sort_values('prop', ascending = False, inplace = True)
    return df

# %%
def get_freq_and_prop(data, var):
    # get time series data
    assert data in ['papers', 'authors'], 'data is wrong!'
    if data == 'papers':
        dic = yearly_papernum_dic
        df = papers.groupby(['year', var]).size().to_frame('freq').reset_index()
        df['year total'] = [dic[x] for x in df.year]
    else:
        dic = yearly_authornum_dic
        df = authors.groupby(['year', var]).size().to_frame('freq').reset_index()
        df['year total'] = [dic[x] for x in df.year]
    df['prop'] = round(df['freq'] / df['year total'], 3)
    return df

# %%
def transform_year(df):
    dff = df.copy()
    dff['year'] = pd.to_datetime(dff['year'] , format='%Y')
    return dff

# %%
authors = pd.read_csv('../data/processed/authors_to_study_expanded.csv')
papers = pd.read_csv('../data/processed/papers_to_study_expanded.csv')
papers.replace({
    True: 'Yes',
    False: 'No'
}, inplace = True)

# %%
top_num = 5
top_country_dic = dict(Counter(authors['countrypred']).most_common(top_num))
top_country = list(top_country_dic.keys())
authors['countrypred_new'] = authors['countrypred'].apply(
        lambda x: x if x in top_country else 'Other'
    )

# %%
for i in [papers, authors]:
    i.replace({
        'Communication Theory': 'CT',
        'Communication, Culture and Critique': 'CCC',
        'Human Communication Research': 'HCR',
        'Journal of Communication': 'JOC',
        'Journal of Computer-Mediated Communication': 'JCMC'
                      }, inplace = True)

# %%
total_paper_num = len(papers)
total_author_num = len(authors)

# %%
total_paper_num, total_author_num
# Out:
# (5712, 11292)

# %%
yearly_papernum = papers.groupby(
    'year').size().to_frame(name='freq').reset_index()
yearly_authornum = authors.groupby(
    'year').size().to_frame(name='freq').reset_index()
yearly_authornum_dic = dict(zip(yearly_authornum.year, yearly_authornum.freq))
yearly_papernum_dic = dict(zip(yearly_papernum.year, yearly_papernum.freq))

# %% [markdown]
# ## Gender

# %%
get_simple_prop_df('authors', 'genderpred')
# Out:
#   genderpred  freq   prop
# 1          M  6876  0.609
# 0          F  4405  0.390
# 2          N    11  0.001

# %%
gender_ts = get_freq_and_prop(data = 'authors', var = 'genderpred')
gender_ts.head(10)
# Out:
#    year genderpred  freq  year total   prop
# 0  1951          M    24          24  1.000
# 1  1952          F     5          25  0.200
# 2  1952          M    20          25  0.800
# 3  1953          M    17          17  1.000
# 4  1954          M    16          16  1.000
# 5  1955          M    11          11  1.000
# 6  1956          M    14          14  1.000
# 7  1957          F     3          19  0.158
# 8  1957          M    16          19  0.842
# 9  1958          M    13          13  1.000

# %%
gender_ts[gender_ts.genderpred == 'F'].sort_values('year')
# Out:
#      year genderpred  freq  year total   prop
# 1    1952          F     5          25  0.200
# 7    1957          F     3          19  0.158
# 10   1959          F     5          21  0.238
# 12   1960          F     3          17  0.176
# 14   1961          F     1          24  0.042
# 17   1963          F     1          30  0.033
# 19   1964          F     3          29  0.103
# 21   1965          F     2          19  0.105
# 24   1967          F     1           9  0.111
# 26   1968          F     7          41  0.171
# 28   1969          F     4          39  0.103
# 30   1970          F     6          33  0.182
# 32   1971          F     4          37  0.108
# 34   1972          F    10          51  0.196
# 36   1973          F     1          18  0.056
# 38   1974          F    23          91  0.253
# 40   1975          F    41         159  0.258
# 42   1976          F    32         178  0.180
# 44   1977          F    52         217  0.240
# 46   1978          F    43         181  0.238
# 48   1979          F    39         182  0.214
# 50   1980          F    53         204  0.260
# 52   1981          F    49         157  0.312
# 54   1982          F    40         136  0.294
# 56   1983          F    33         144  0.229
# 64   1987          F    35          93  0.376
# 87   1998          F    62         164  0.378
# 106  2007          F   124         308  0.403
# 89   1999          F    55         136  0.404
# 108  2008          F   129         304  0.424
# 91   2000          F    74         171  0.433
# 117  2012          F   152         348  0.437
# 125  2015          F   176         402  0.438
# 99   2004          F   109         248  0.440
# 104  2006          F   138         311  0.444
# 102  2005          F   142         318  0.447
# 111  2009          F   150         335  0.448
# 127  2016          F   158         352  0.449
# 95   2002          F   119         263  0.452
# 93   2001          F    80         177  0.452
# 122  2014          F   197         431  0.457
# 97   2003          F    98         214  0.458
# 115  2011          F   145         308  0.471
# 137  2020          F   141         299  0.472
# 113  2010          F   140         295  0.475
# 132  2018          F   176         368  0.478
# 142  2022          F   100         200  0.500
# 140  2021          F   229         455  0.503
# 119  2013          F   179         355  0.504
# 129  2017          F   180         352  0.511
# 135  2019          F   140         269  0.520

# %%
gender_ts[gender_ts.genderpred == 'N']
# Out:
#      year genderpred  freq  year total   prop
# 86   1997          N     1         164  0.006
# 101  2004          N     1         248  0.004
# 110  2008          N     1         304  0.003
# 121  2013          N     1         355  0.003
# 124  2014          N     1         431  0.002
# 131  2017          N     2         352  0.006
# 134  2018          N     1         368  0.003
# 139  2020          N     1         299  0.003
# 144  2022          N     2         200  0.010

# %%
gender_ts[gender_ts.genderpred == 'N'].freq.sum()
# Out:
# 11

# %%
# gender_ts['year'] = pd.to_datetime(gender_ts['year'], format='%Y')

gender_stack_chart = alt.Chart(gender_ts).mark_bar().encode(
    x = alt.X(
        'year:N',
        axis = alt.Axis(
            tickCount= 4,
            labelAngle = -45
    )
    ),
    y = alt.Y(
        'sum(freq)',
        title = '# of Authors'
    ),
    color = alt.Color(
        'genderpred',
        title = 'Gender',
        scale = alt.Scale(
            domain = ['M', 'F', 'N'],
            range = ['steelblue', 'orange', 'pink']
        )
    )
).properties(
    title = 'a',
    height=300,
    width=260
)

gender_stack_chart
# Out:
# alt.Chart(...)

# %%
gender_ts_prop_chart = alt.Chart(transform_year(gender_ts)).mark_line().encode(
    x = alt.X(
        'year',
        title = 'Year'
    ),
    y = alt.Y(
        'prop',
        title = 'Proportion'
    ),
    color = alt.Color(
        'genderpred',
        title = 'Gender',
        scale = alt.Scale(
            domain = ['M', 'F', 'N'],
            range = ['steelblue', 'orange', 'pink']
        )
    )
).properties(
    title = 'b',
    height=300,
    width=260
)

gender_ts_prop_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## First author gender

# %%
get_simple_prop_df(data = 'papers', var = 'first_author_gender')
# Out:
#   first_author_gender  freq   prop
# 1                   M  3699  0.648
# 0                   F  2003  0.351
# 2                   N    10  0.002

# %%
first_author_gender_ts = get_freq_and_prop(data = 'papers', var = 'first_author_gender')
first_author_gender_ts
# Out:
#      year first_author_gender  freq  year total   prop
# 0    1951                   M    20          20  1.000
# 1    1952                   F     5          24  0.208
# 2    1952                   M    19          24  0.792
# 3    1953                   M    17          17  1.000
# 4    1954                   M    15          15  1.000
# 5    1955                   M    11          11  1.000
# 6    1956                   M    13          13  1.000
# 7    1957                   F     2          16  0.125
# 8    1957                   M    14          16  0.875
# 9    1958                   M    13          13  1.000
# 10   1959                   F     3          17  0.176
# 11   1959                   M    14          17  0.824
# 12   1960                   F     3          16  0.188
# 13   1960                   M    13          16  0.812
# 14   1961                   M    21          21  1.000
# 15   1962                   M    18          18  1.000
# 16   1963                   F     1          24  0.042
# 17   1963                   M    23          24  0.958
# 18   1964                   F     3          21  0.143
# 19   1964                   M    18          21  0.857
# 20   1965                   F     1          17  0.059
# 21   1965                   M    16          17  0.941
# 111  2010                   M    83         139  0.597
# 112  2011                   F    68         138  0.493
# 113  2011                   M    70         138  0.507
# 114  2012                   F    72         163  0.442
# 115  2012                   M    91         163  0.558
# 116  2013                   F    79         154  0.513
# 117  2013                   M    74         154  0.481
# 118  2013                   N     1         154  0.006
# 119  2014                   F    93         187  0.497
# 120  2014                   M    93         187  0.497
# 121  2014                   N     1         187  0.005
# 122  2015                   F    67         165  0.406
# 123  2015                   M    98         165  0.594
# 124  2016                   F    68         159  0.428
# 125  2016                   M    91         159  0.572
# 126  2017                   F    79         153  0.516
# 127  2017                   M    72         153  0.471
# 128  2017                   N     2         153  0.013
# 129  2018                   F    70         157  0.446
# 130  2018                   M    86         157  0.548
# 131  2018                   N     1         157  0.006
# 132  2019                   F    67         121  0.554
# 133  2019                   M    54         121  0.446
# 134  2020                   F    58         131  0.443
# 135  2020                   M    72         131  0.550
# 136  2020                   N     1         131  0.008
# 137  2021                   F    88         167  0.527
# 138  2021                   M    79         167  0.473
# 139  2022                   F    37          78  0.474
# 140  2022                   M    40          78  0.513
# 141  2022                   N     1          78  0.013

# %%
alt.Chart(transform_year(first_author_gender_ts)).mark_line().encode(
    x = alt.X(
        'year',
        title = 'Year'
    ),
    y = alt.Y(
        'prop',
        title = 'Proportion'
    ),
    color = alt.Color(
        'first_author_gender',
        title = 'First author gender',
        scale = alt.Scale(
            domain = ['M', 'F', 'N'],
            range = ['steelblue', 'orange', 'pink']
        )
    )
).properties(
    title = 'b',
    height=300,
    width=260
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Gender parity for white people

# %%
authors.shape
# Out:
# (11292, 44)

# %%
white_authors = authors[authors.racepred == 'White']
white_authors.head(2)
# Out:
#                   authorID                  doi  \
# 0  10.1093/joc/jqac004+1.0  10.1093/joc/jqac004
# 2  10.1093/joc/jqac009+1.0  10.1093/joc/jqac009
#
#                                                      url  year  \
# 0  https://academic.oup.com/joc/article/72/3/297/6529454  2022
# 2  https://academic.oup.com/joc/article/72/3/322/6549217  2022
#
#                                                                                                 title  \
# 0  The Gender Divide in Wikipedia: Quantifying and Assessing the Impact of Two Feminist Interventions
# 2       Mapping Exposure Diversity: The Divergent Effects of Algorithmic Curation on News Consumption
#
#   journal  numberOfAuthors  authorPosition     authorFullName firstName  \
# 0     JOC              2.0             1.0  Isabelle Langrock  Isabelle
# 2     JOC              2.0             1.0     Pascal Jürgens    Pascal
#
#    lastName  \
# 0  Langrock
# 2   Jürgens
#
#                                                                                                                             affiliation  \
# 0                                         Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
# 2  Department of Communication, Jakob-Welder-Weg 12, Johannes Gutenberg-Universität Mainz , 55099 Mainz, Rhineland-Palatinate,  Germany
#
#                                                                    gscholarLink  \
# 0  https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Isabelle+Langrock
# 2     https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Pascal+Jürgens
#
#                                                                                                                                                                googleSearch  \
# 0                                       https://www.google.com/search?q=Isabelle+Langrock+annenberg+school+for+communication+university+of+pennsylvania+philadelphia+pa+usa
# 2  https://www.google.com/search?q=Pascal+J%C3%BCrgens+department+of+communication+jakob+welder+weg+johannes+gutenberg+universit+t+mainz+mainz+rhineland+palatinate+germany
#
#   genderize  genderize_prob  genderize_basedon genderAccuracy  \
# 0    female            0.99            89728.0           High
# 2      male            0.99            84147.0           High
#
#     authorFullName.1 firstName.1 lastName.1  \
# 0  Isabelle Langrock    Isabelle   Langrock
# 2     Pascal Jürgens      Pascal    Jürgens
#
#                                                                                                                           affiliation.1  \
# 0                                         Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
# 2  Department of Communication, Jakob-Welder-Weg 12, Johannes Gutenberg-Universität Mainz , 55099 Mainz, Rhineland-Palatinate,  Germany
#
#                                                                  gscholarLink.1  \
# 0  https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Isabelle+Langrock
# 2     https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Pascal+Jürgens
#
#                                                                                                                                                              googleSearch.1  \
# 0                                       https://www.google.com/search?q=Isabelle+Langrock+annenberg+school+for+communication+university+of+pennsylvania+philadelphia+pa+usa
# 2  https://www.google.com/search?q=Pascal+J%C3%BCrgens+department+of+communication+jakob+welder+weg+johannes+gutenberg+universit+t+mainz+mainz+rhineland+palatinate+germany
#
#     race racePredAccuracy       api     black  hispanic     white  \
# 0  white             High  0.007762  0.066429  0.030049  0.895760
# 2  white             High  0.007112  0.088763  0.031022  0.873102
#
#    raceHighest  raceSecondHighest  raceDiff  \
# 0     0.895760           0.066429  0.829331
# 2     0.873102           0.088763  0.784340
#
#                                                                                                            affProcessed  \
# 0                                     annenberg school for communication university of pennsylvania philadelphia pa usa
# 2  department of communication jakob welder weg johannes gutenberg universit t mainz mainz rhineland palatinate germany
#
#                                                                                                                           affiliation.2  \
# 0                                         Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
# 2  Department of Communication, Jakob-Welder-Weg 12, Johannes Gutenberg-Universität Mainz , 55099 Mainz, Rhineland-Palatinate,  Germany
#
#                               ROR_AFFNAME matchMethod  \
# 0              University of Pennsylvania       Exact
# 2  Johannes Gutenberg University of Mainz   API_QUERY
#
#                       ROR_ID type countrypred genderpred racepred afftypepred  \
# 0  https://ror.org/00b30xv10    R          US          F    White   Education
# 2  https://ror.org/023b0x485    R          DE          M    White   Education
#
#   countrypred_new
# 0              US
# 2              DE

# %%
white_authors.shape
# Out:
# (9304, 44)

# %%
Counter(white_authors.genderpred)
# Out:
# Counter({'F': 3430, 'M': 5869, 'N': 5})

# %%
3430/white_authors.shape[0]
# Out:
# 0.36865864144453997

# %%
5869/white_authors.shape[0]
# Out:
# 0.6308039552880481

# %%
yearly_white_authornum = white_authors.groupby(
    'year').size().to_frame(name='freq').reset_index()
yearly_white_authornum_dic = dict(zip(yearly_white_authornum.year, yearly_white_authornum.freq))

# %%
def get_freq_and_prop_for_white_authors(data, var):
    dic = yearly_white_authornum_dic
    df = data.groupby(['year', var]).size().to_frame('freq').reset_index()
    df['year total'] = [dic[x] for x in df.year]
    df['prop'] = round(df['freq'] / df['year total'], 3)
    return df

# %%
white_gender_ts = get_freq_and_prop_for_white_authors(data = white_authors, var = 'genderpred')
white_gender_ts.head(10)
# Out:
#    year genderpred  freq  year total   prop
# 0  1951          M    24          24  1.000
# 1  1952          F     3          23  0.130
# 2  1952          M    20          23  0.870
# 3  1953          M    14          14  1.000
# 4  1954          M    16          16  1.000
# 5  1955          M    11          11  1.000
# 6  1956          M    14          14  1.000
# 7  1957          F     3          17  0.176
# 8  1957          M    14          17  0.824
# 9  1958          M    13          13  1.000

# %%
alt.Chart(transform_year(white_gender_ts)).mark_line().encode(
    x = alt.X(
        'year',
        title = 'Year'
    ),
    y = alt.Y(
        'prop',
        title = 'Proportion'
    ),
    color = alt.Color(
        'genderpred',
        title = 'White author gender',
        scale = alt.Scale(
            domain = ['M', 'F', 'N'],
            range = ['steelblue', 'orange', 'pink']
        )
    )
).properties(
    title = 'b',
    height=300,
    width=260
)
# Out:
# alt.Chart(...)
