# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import altair as alt
from altair import datum

# %%
papers = pd.read_csv('../data/papers_to_study_expanded.csv')
set(papers.journal)
# Out:
# {'Communication Theory',
#  'Communication, Culture and Critique',
#  'Human Communication Research',
#  'Journal of Communication',
#  'Journal of Computer-Mediated Communication'}

# %%
# joc
joc = papers[papers.journal == 'Journal of Communication'].sort_values(by="year", ascending= True)
joc.head(1)
# Out:
#                        journal  year  category type  cross_country  \
# 2625  Journal of Communication  1951  Articles    R          False
#
#       cross_type  cross_gender  cross_race  num_race  num_country  ...  \
# 2625        True         False       False         1            1  ...
#
#       cross_gender_race_and_country  numberOfAuthors  first_author_gender  \
# 2625                          False              2.0                    M
#
#       first_author_race  first_author_country first_author_afftype  \
# 2625              White                    US            Education
#
#      with_us_authors cross_race_details cross_gender_details  \
# 2625            True         White only               M only
#
#       gscholar_citation
# 2625                0.0
#
# [1 rows x 23 columns]

# %%
# ccc
ccc = papers[papers.journal == 'Communication, Culture and Critique'].sort_values(by="year", ascending= True)
ccc.head(1)
# Out:
#                                   journal  year           category type  \
# 5711  Communication, Culture and Critique  2008  Original Articles    R
#
#       cross_country  cross_type  cross_gender  cross_race  num_race  \
# 5711          False       False         False       False         1
#
#       num_country  ...  cross_gender_race_and_country  numberOfAuthors  \
# 5711            1  ...                          False              1.0
#
#       first_author_gender  first_author_race  first_author_country  \
# 5711                    M              White                    US
#
#      first_author_afftype with_us_authors cross_race_details  \
# 5711            Education            True         White only
#
#      cross_gender_details  gscholar_citation
# 5711               M only               52.0
#
# [1 rows x 23 columns]

# %%
ccc.shape
# Out:
# (459, 23)

# %%
hcr = papers[papers.journal == 'Human Communication Research'].sort_values(by="year", ascending= True)
hcr.head(1)
# Out:
#                            journal  year  category type  cross_country  \
# 3778  Human Communication Research  1974  Articles    R          False
#
#       cross_type  cross_gender  cross_race  num_race  num_country  ...  \
# 3778       False         False       False         1            1  ...
#
#       cross_gender_race_and_country  numberOfAuthors  first_author_gender  \
# 3778                          False              1.0                    M
#
#       first_author_race  first_author_country first_author_afftype  \
# 3778              White                    US            Education
#
#      with_us_authors cross_race_details cross_gender_details  \
# 3778            True         White only               M only
#
#       gscholar_citation
# 3778                8.0
#
# [1 rows x 23 columns]

# %%
jcmc = papers[papers.journal == 'Journal of Computer-Mediated Communication'].sort_values(by="year", ascending= True)
jcmc.head(1)
# Out:
#                                          journal  year          category type  \
# 5252  Journal of Computer-Mediated Communication  1995  Original Article    R
#
#       cross_country  cross_type  cross_gender  cross_race  num_race  \
# 5252          False       False         False       False         1
#
#       num_country  ...  cross_gender_race_and_country  numberOfAuthors  \
# 5252            1  ...                          False              1.0
#
#       first_author_gender  first_author_race  first_author_country  \
# 5252                    M              White                    US
#
#      first_author_afftype with_us_authors cross_race_details  \
# 5252            Education            True         White only
#
#      cross_gender_details  gscholar_citation
# 5252               M only               20.0
#
# [1 rows x 23 columns]

# %%
ct = papers[papers.journal == 'Communication Theory'].sort_values(by="year", ascending= True)
ct.head(1)
# Out:
#                    journal  year            category type  cross_country  \
# 4407  Communication Theory  1991  Comparative Theory    R          False
#
#       cross_type  cross_gender  cross_race  num_race  num_country  ...  \
# 4407       False         False       False         1            1  ...
#
#       cross_gender_race_and_country  numberOfAuthors  first_author_gender  \
# 4407                          False              1.0                    F
#
#       first_author_race  first_author_country first_author_afftype  \
# 4407              White                    US            Education
#
#      with_us_authors cross_race_details cross_gender_details  \
# 4407            True         White only               F only
#
#       gscholar_citation
# 4407              101.0
#
# [1 rows x 23 columns]
