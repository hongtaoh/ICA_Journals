# %% [markdown]
# ## Aim
#
# The aim of this notebook is to get a small sample of the author data (500 authors) and predict their gender and race, and also their affiliation type and country origin.

# %%
import pandas as pd
import requests
import math
import string
import re
import numpy as np
from collections import Counter

# %%
df = pd.read_csv('../data/interim/ica_author_data_research_paper_only.csv')

# %%
df.head(1)
# Out:
#                    doi                                                url  \
# 0  10.1093/joc/jqab054  https://academic.oup.com/joc/article/72/2/145/...
#
#                                                title  \
# 0  Media Systems in the Digital Age: An Empirical...
#
#                     journal datePublished      authorName  numberOfAuthors  \
# 0  Journal of Communication    2022-01-17  Edda Humprecht              5.0
#
#    authorPosition                                        affiliation
# 0             1.0  Department of Communication and Media Research...

# %%
df[df.authorName.isnull()].shape
# Out:
# (197, 9)

# %%
# keep only rows where authorName is nontnull
df = df[df.authorName.notnull()]

# %%
full_names = df.authorName

# %%
full_names[0].split(' ')[0]
# Out:
# 'Edda'

# %%
# parsing names
df['firstName'] = [full_name.split(' ')[0] for full_name in full_names]
df['lastName'] = [full_name.split(' ')[-1] for full_name in full_names]

# %%
# get a sample
df_small = df.sample(500, 
                     random_state = 42, 
                     ignore_index = True
                    )

# %%
df_small.head(2)
# Out:
#                                 doi  \
# 0                10.1093/joc/jqz040
# 1  10.1111/j.1468-2958.2010.01395.x
#
#                                                  url  \
# 0  https://academic.oup.com/joc/article/70/1/13/5...
# 1  https://academic.oup.com/hcr/article/37/1/107/...
#
#                                                title  \
# 0  How the Comforting Process Fails: Psychologica...
# 1  Does Mother Know Best? An Actor–Partner Model ...
#
#                         journal datePublished             authorName  \
# 0      Journal of Communication    2020-02-18  Kellie St.Cyr Brisini
# 1  Human Communication Research    2011-01-01      Janice L. Krieger
#
#    numberOfAuthors  authorPosition  \
# 0              3.0             3.0
# 1              4.0             1.0
#
#                                          affiliation firstName lastName
# 0  Department of Communication Arts and Sciences ...    Kellie  Brisini
# 1  1 School of Communication, The Ohio State Univ...    Janice  Krieger

# %% [markdown]
# ## Genderize.io

# %%
# guessedGender = []
# probability = []
# basedOn = []
# for firstName in df_small['firstName']:
#     response = requests.get('https://api.genderize.io/?name=' + firstName)
#     j = response.json()
#     gender = j['gender']
#     prob = str(j['probability'])
#     count = str(j['count'])
#     guessedGender.append(gender)
#     probability.append(prob)
#     basedOn.append(count)

# %%
df_small['gender'] = guessedGender
df_small['gender_prob'] = probability
df_small['gender_basedon'] = basedOn

# %%
df_small.head()
# Out:
#                                 doi  \
# 0                10.1093/joc/jqz040
# 1  10.1111/j.1468-2958.2010.01395.x
# 2  10.1111/j.1753-9137.2009.01055.x
# 3                10.1111/hcre.12067
# 4  10.1111/j.1083-6101.2011.01539.x
#
#                                                  url  \
# 0  https://academic.oup.com/joc/article/70/1/13/5...
# 1  https://academic.oup.com/hcr/article/37/1/107/...
# 2  https://academic.oup.com/ccc/article/3/1/21/40...
# 3  https://academic.oup.com/hcr/article/42/1/71/4...
# 4  https://academic.oup.com/jcmc/article/16/2/271...
#
#                                                title  \
# 0  How the Comforting Process Fails: Psychologica...
# 1  Does Mother Know Best? An Actor–Partner Model ...
# 2  The Exceptional Community: On Strangers, Forei...
# 3  Consciousness and Self-Regulation in Mobile Co...
# 4  Two Routes Leading to Conformity Intention in ...
#
#                                       journal datePublished  \
# 0                    Journal of Communication    2020-02-18
# 1                Human Communication Research    2011-01-01
# 2         Communication, Culture and Critique    2010-02-22
# 3                Human Communication Research    2016-01-01
# 4  Journal of Computer-Mediated Communication    2011-01-01
#
#               authorName  numberOfAuthors  authorPosition  \
# 0  Kellie St.Cyr Brisini              3.0             3.0
# 1      Janice L. Krieger              4.0             1.0
# 2     Garnet C. Butchart              1.0             1.0
# 3      Scott W. Campbell              4.0             3.0
# 4           Junghyun Kim              1.0             1.0
#
#                                          affiliation firstName  lastName  \
# 0  Department of Communication Arts and Sciences ...    Kellie   Brisini
# 1  1 School of Communication, The Ohio State Univ...    Janice   Krieger
# 2  1 Department of Communication, University of S...    Garnet  Butchart
# 3  1 Communication Studies, University of Michiga...     Scott  Campbell
# 4                                                NaN  Junghyun       Kim
#
#    gender gender_prob gender_basedon
# 0  female        0.97           1170
# 1  female        0.98           6277
# 2    male        0.68            171
# 3    male        0.99          31815
# 4    male        0.62            257

# %%
gscholar_str = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q='

# %%
# gscholar_str + '+'.join(df_small['authorName'][0].split(' '))
# Out:
# 'https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Kellie+St.Cyr+Brisini'

# %%
gscholar_str + df_small['firstName'][0] + '+' + df_small['lastName'][0]
# Out:
# 'https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Kellie+Brisini'

# %%
df_small['gscholarLink'] = [
    gscholar_str + df_small['firstName'][i] + '+' + df_small['lastName'][i] for i in range(len(df_small))]

# %%
df_small['gscholarLink'][10]
# Out:
# 'https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Scott+Alter'

# %%
# df_small.to_csv('../data/interim/500_author.csv', index=False)

# %% [markdown]
# ## Gender API

# %%
df_small['firstName'][0]
# Out:
# 'Kellie'

# %%
# response = requests.get(
#     'https://gender-api.com/get?name='+ 
#     df_small['firstName'][0] + 
#     '&key=Cph74gYuG5d55qn2ccqdPBMgreSytzaUMaZU')

# %%
# j = response.json()

# %% [markdown]
# {'name': 'kellie',
#  'name_sanitized': 'Kellie',
#  'country': '',
#  'gender': 'female',
#  'samples': 2598,
#  'accuracy': 98,
#  'duration': '15ms',
#  'credits_used': 1}

# %%
guessedGender_2 = []
probability_2 = []
basedOn_2 = []
for firstName in df_small['firstName']:
    response = requests.get('https://gender-api.com/get?name='+ firstName + 
                            '&key=Cph74gYuG5d55qn2ccqdPBMgreSytzaUMaZU')
    j = response.json()
    gender = j['gender']
    prob = j['accuracy']
    count = j['samples']
    guessedGender_2.append(gender)
    probability_2.append(prob)
    basedOn_2.append(count)

# %%
df_small['gender_api'] = guessedGender_2
df_small['gender_accu'] = probability_2
df_small['gender_samples'] = basedOn_2

# %%
# Some names are wierd. For example, only a letter for first name
df_small[df_small.gender != df_small.gender_api].shape
# Out:
# (30, 18)

# %% [markdown]
# ## Race

# %%
from ethnicolr import census_ln, pred_census_ln

# %%
df_small_race_predicted = pred_census_ln(df_small, 'lastName', year=2010)

# %%
df_small_race_predicted.shape
# Out:
# (500, 23)

# %% [markdown]
# ## ROR

# %%
df_small[df_small.affiliation.isnull()]
# Out:
#                                     doi  \
# 4      10.1111/j.1083-6101.2011.01539.x
# 68   10.1111/j.1460-2466.1973.tb00951.x
# 184  10.1111/j.1460-2466.1973.tb00952.x
# 303  10.1111/j.1460-2466.1966.tb00041.x
# 358  10.1111/j.1460-2466.1967.tb01195.x
# 420                  10.1093/ccc/tcz022
#
#                                                    url  \
# 4    https://academic.oup.com/jcmc/article/16/2/271...
# 68   https://academic.oup.com/joc/article/23/3/315/...
# 184  https://academic.oup.com/joc/article/23/3/328/...
# 303  https://academic.oup.com/joc/article/16/4/273/...
# 358  https://academic.oup.com/joc/article/17/4/372/...
# 420  https://academic.oup.com/ccc/article/12/3/434/...
#
#                                                  title  \
# 4    Two Routes Leading to Conformity Intention in ...
# 68            Information Utilization and Personality1
# 184  Optimal Heterophily and Communication Effectiv...
# 303                 Nationality and Social Perception1
# 358  Some Effects of Priming, Incubation and Creati...
# 420  Corrigendum to “A Shoppable Life: Performance,...
#
#                                         journal datePublished  \
# 4    Journal of Computer-Mediated Communication    2011-01-01
# 68                     Journal of Communication    2006-02-07
# 184                    Journal of Communication    2006-02-07
# 303                    Journal of Communication    2006-02-07
# 358                    Journal of Communication    2006-02-07
# 420         Communication, Culture and Critique    2019-05-03
#
#              authorName  numberOfAuthors  authorPosition affiliation  \
# 4          Junghyun Kim              1.0             1.0         NaN
# 68     Jerome B. Kernan              2.0             1.0         NaN
# 184  W. Thomas Anderson              2.0             2.0         NaN
# 303        Bryant Wedge              1.0             1.0         NaN
# 358     Mehvin D. Lynch              2.0             1.0         NaN
# 420          Emily Hund              2.0             1.0         NaN
#
#     firstName  lastName  gender gender_prob gender_basedon  \
# 4    Junghyun       Kim    male        0.62            257
# 68     Jerome    Kernan    male        0.99          55481
# 184        W.  Anderson    None           0              0
# 303    Bryant     Wedge    male        0.98            815
# 358    Mehvin     Lynch    None           0              0
# 420     Emily      Hund  female        0.98          16379
#
#                                           gscholarLink gender_api  \
# 4    https://scholar.google.com/scholar?hl=en&as_sd...       male
# 68   https://scholar.google.com/scholar?hl=en&as_sd...       male
# 184  https://scholar.google.com/scholar?hl=en&as_sd...       male
# 303  https://scholar.google.com/scholar?hl=en&as_sd...       male
# 358  https://scholar.google.com/scholar?hl=en&as_sd...    unknown
# 420  https://scholar.google.com/scholar?hl=en&as_sd...     female
#
#      gender_accu  gender_samples
# 4             72             152
# 68            99           35619
# 184           80             260
# 303           99            1643
# 358            0               0
# 420           98           36641

# %%
df_small['affiliation'][0]
# Out:
# 'Department of Communication Arts and Sciences , The Pennsylvania State University, University Park, PA 16802,  USA'

# %%
def notNaN(num):
    return num == num

# %%
notNaN(df_small['affiliation'][4])
# Out:
# False

# %%
def process_text(aff):
    aff = aff.lower()
    aff = re.sub('[^a-z ]+', ' ', aff)
    aff = ' '.join(aff.split())
    return aff

# %%
ror_id_list = []
ror_affname_list = []
ror_afftype_list = []
us_state_list = []
ror_country_list = []
idx = 0
for aff in df_small['affiliation']:
    if notNaN(aff):
        aff = process_text(aff)
        response = requests.get('https://api.ror.org/organizations?query='+aff)
        j = response.json()
        j = j['items'][0]
        try:
            ror_id = j['id']
        except:
            ror_id = None
        try:
            ror_affname = j['name']
        except:
            ror_affname = None
        try:
            ror_afftype = j['types'][0]
        except:
            ror_afftype = None
        try:
            us_state = j['addresses'][0]['state']
        except:
            us_state = None
        try:
            ror_country = j['country']['country_code']
        except:
            ror_country = None
        ror_id_list.append(ror_id)
        ror_affname_list.append(ror_affname)
        ror_afftype_list.append(ror_afftype)
        us_state_list.append(us_state)
        ror_country_list.append(ror_country)
    else:
        ror_id_list.append(None)
        ror_affname_list.append(None)
        ror_afftype_list.append(None)
        us_state_list.append(None)
        ror_country_list.append(None)
    print(f'{idx} is done')
    idx += 1
# Out:
# 0 is done
# 1 is done
# 2 is done
# 3 is done
# 4 is done
# 5 is done
# 6 is done
# 7 is done
# 8 is done
# 9 is done
# 10 is done
# 11 is done
# 12 is done
# 13 is done
# 14 is done
# 15 is done
# 16 is done
# 17 is done
# 18 is done
# 19 is done
# 20 is done
# 21 is done
# 22 is done
# 23 is done
# 24 is done
# 25 is done
# 26 is done
# 27 is done
# 28 is done
# 29 is done
# 30 is done
# 31 is done
# 32 is done
# 33 is done
# 34 is done
# 35 is done
# 36 is done
# 37 is done
# 38 is done
# 39 is done
# 40 is done
# 41 is done
# 42 is done
# 43 is done
# 44 is done
# 45 is done
# 46 is done
# 47 is done
# 48 is done
# 49 is done
# 50 is done
# 51 is done
# 52 is done
# 53 is done
# 54 is done
# 55 is done
# 56 is done
# 57 is done
# 58 is done
# 59 is done
# 60 is done
# 61 is done
# 62 is done
# 63 is done
# 64 is done
# 65 is done
# 66 is done
# 67 is done
# 68 is done
# 69 is done
# 70 is done
# 71 is done
# 72 is done
# 73 is done
# 74 is done
# 75 is done
# 76 is done
# 77 is done
# 78 is done
# 79 is done
# 80 is done
# 81 is done
# 82 is done
# 83 is done
# 84 is done
# 85 is done
# 86 is done
# 87 is done
# 88 is done
# 89 is done
# 90 is done
# 91 is done
# 92 is done
# 93 is done
# 94 is done
# 95 is done
# 96 is done
# 97 is done
# 98 is done
# 99 is done
# 100 is done
# 101 is done
# 102 is done
# 103 is done
# 104 is done
# 105 is done
# 106 is done
# 107 is done
# 108 is done
# 109 is done
# 110 is done
# 111 is done
# 112 is done
# 113 is done
# 114 is done
# 115 is done
# 116 is done
# 117 is done
# 118 is done
# 119 is done
# 120 is done
# 121 is done
# 122 is done
# 123 is done
# 124 is done
# 125 is done
# 126 is done
# 127 is done
# 128 is done
# 129 is done
# 130 is done
# 131 is done
# 132 is done
# 133 is done
# 134 is done
# 135 is done
# 136 is done
# 137 is done
# 138 is done
# 139 is done
# 140 is done
# 141 is done
# 142 is done
# 143 is done
# 144 is done
# 145 is done
# 146 is done
# 147 is done
# 148 is done
# 149 is done
# 150 is done
# 151 is done
# 152 is done
# 153 is done
# 154 is done
# 155 is done
# 156 is done
# 157 is done
# 158 is done
# 159 is done
# 160 is done
# 161 is done
# 162 is done
# 163 is done
# 164 is done
# 165 is done
# 166 is done
# 167 is done
# 168 is done
# 169 is done
# 170 is done
# 171 is done
# 172 is done
# 173 is done
# 174 is done
# 175 is done
# 176 is done
# 177 is done
# 178 is done
# 179 is done
# 180 is done
# 181 is done
# 182 is done
# 183 is done
# 184 is done
# 185 is done
# 186 is done
# 187 is done
# 188 is done
# 189 is done
# 190 is done
# 191 is done
# 192 is done
# 193 is done
# 194 is done
# 195 is done
# 196 is done
# 197 is done
# 198 is done
# 199 is done
# 200 is done
# 201 is done
# 202 is done
# 203 is done
# 204 is done
# 205 is done
# 206 is done
# 207 is done
# 208 is done
# 209 is done
# 210 is done
# 211 is done
# 212 is done
# 213 is done
# 214 is done
# 215 is done
# 216 is done
# 217 is done
# 218 is done
# 219 is done
# 220 is done
# 221 is done
# 222 is done
# 223 is done
# 224 is done
# 225 is done
# 226 is done
# 227 is done
# 228 is done
# 229 is done
# 230 is done
# 231 is done
# 232 is done
# 233 is done
# 234 is done
# 235 is done
# 236 is done
# 237 is done
# 238 is done
# 239 is done
# 240 is done
# 241 is done
# 242 is done
# 243 is done
# 244 is done
# 245 is done
# 246 is done
# 247 is done
# 248 is done
# 249 is done
# 250 is done
# 251 is done
# 252 is done
# 253 is done
# 254 is done
# 255 is done
# 256 is done
# 257 is done
# 258 is done
# 259 is done
# 260 is done
# 261 is done
# 262 is done
# 263 is done
# 264 is done
# 265 is done
# 266 is done
# 267 is done
# 268 is done
# 269 is done
# 270 is done
# 271 is done
# 272 is done
# 273 is done
# 274 is done
# 275 is done
# 276 is done
# 277 is done
# 278 is done
# 279 is done
# 280 is done
# 281 is done
# 282 is done
# 283 is done
# 284 is done
# 285 is done
# 286 is done
# 287 is done
# 288 is done
# 289 is done
# 290 is done
# 291 is done
# 292 is done
# 293 is done
# 294 is done
# 295 is done
# 296 is done
# 297 is done
# 298 is done
# 299 is done
# 300 is done
# 301 is done
# 302 is done
# 303 is done
# 304 is done
# 305 is done
# 306 is done
# 307 is done
# 308 is done
# 309 is done
# 310 is done
# 311 is done
# 312 is done
# 313 is done
# 314 is done
# 315 is done
# 316 is done
# 317 is done
# 318 is done
# 319 is done
# 320 is done
# 321 is done
# 322 is done
# 323 is done
# 324 is done
# 325 is done
# 326 is done
# 327 is done
# 328 is done
# 329 is done
# 330 is done
# 331 is done
# 332 is done
# 333 is done
# 334 is done
# 335 is done
# 336 is done
# 337 is done
# 338 is done
# 339 is done
# 340 is done
# 341 is done
# 342 is done
# 343 is done
# 344 is done
# 345 is done
# 346 is done
# 347 is done
# 348 is done
# 349 is done
# 350 is done
# 351 is done
# 352 is done
# 353 is done
# 354 is done
# 355 is done
# 356 is done
# 357 is done
# 358 is done
# 359 is done
# 360 is done
# 361 is done
# 362 is done
# 363 is done
# 364 is done
# 365 is done
# 366 is done
# 367 is done
# 368 is done
# 369 is done
# 370 is done
# 371 is done
# 372 is done
# 373 is done
# 374 is done
# 375 is done
# 376 is done
# 377 is done
# 378 is done
# 379 is done
# 380 is done
# 381 is done
# 382 is done
# 383 is done
# 384 is done
# 385 is done
# 386 is done
# 387 is done
# 388 is done
# 389 is done
# 390 is done
# 391 is done
# 392 is done
# 393 is done
# 394 is done
# 395 is done
# 396 is done
# 397 is done
# 398 is done
# 399 is done
# 400 is done
# 401 is done
# 402 is done
# 403 is done
# 404 is done
# 405 is done
# 406 is done
# 407 is done
# 408 is done
# 409 is done
# 410 is done
# 411 is done
# 412 is done
# 413 is done
# 414 is done
# 415 is done
# 416 is done
# 417 is done
# 418 is done
# 419 is done
# 420 is done
# 421 is done
# 422 is done
# 423 is done
# 424 is done
# 425 is done
# 426 is done
# 427 is done
# 428 is done
# 429 is done
# 430 is done
# 431 is done
# 432 is done
# 433 is done
# 434 is done
# 435 is done
# 436 is done
# 437 is done
# 438 is done
# 439 is done
# 440 is done
# 441 is done
# 442 is done
# 443 is done
# 444 is done
# 445 is done
# 446 is done
# 447 is done
# 448 is done
# 449 is done
# 450 is done
# 451 is done
# 452 is done
# 453 is done
# 454 is done
# 455 is done
# 456 is done
# 457 is done
# 458 is done
# 459 is done
# 460 is done
# 461 is done
# 462 is done
# 463 is done
# 464 is done
# 465 is done
# 466 is done
# 467 is done
# 468 is done
# 469 is done
# 470 is done
# 471 is done
# 472 is done
# 473 is done
# 474 is done
# 475 is done
# 476 is done
# 477 is done
# 478 is done
# 479 is done
# 480 is done
# 481 is done
# 482 is done
# 483 is done
# 484 is done
# 485 is done
# 486 is done
# 487 is done
# 488 is done
# 489 is done
# 490 is done
# 491 is done
# 492 is done
# 493 is done
# 494 is done
# 495 is done
# 496 is done
# 497 is done
# 498 is done
# 499 is done

# %%
df_small_race_predicted['ror_id'] = ror_id_list
df_small_race_predicted['ror_affname'] = ror_affname_list
df_small_race_predicted['ror_afftype'] = ror_afftype_list
df_small_race_predicted['us_state'] = us_state_list
df_small_race_predicted['ror_country'] = ror_country_list

# %%
df_small_race_predicted['genderAgree'] = np.where(
    df_small_race_predicted['gender'] == df_small_race_predicted['gender_api'], 
    True, 
    False)

# %%
df_small_race_predicted['raceNew'] = np.where(
    df_small_race_predicted['race']=='api', 'Asian', df_small_race_predicted['race'])

# %%
df_small_race_predicted.columns
# Out:
# Index(['doi', 'url', 'title', 'journal', 'datePublished', 'authorName',
#        'numberOfAuthors', 'authorPosition', 'affiliation', 'firstName',
#        'lastName', 'gender', 'gender_prob', 'gender_basedon', 'gscholarLink',
#        'gender_api', 'gender_accu', 'gender_samples', 'api', 'black',
#        'hispanic', 'white', 'race', 'ror_id', 'ror_affname', 'ror_afftype',
#        'us_state', 'ror_country', 'genderAgree', 'raceNew'],
#       dtype='object')

# %%
cols_to_keep = [
    'doi',
    'url',
    'title',
    'journal',
    'authorName',
    'gscholarLink',
    'firstName',
    'gender',
    'gender_prob',
    'gender_basedon',
    'genderAgree',
    'gender_api',
    'gender_accu',
    'gender_samples',
    'lastName',
    'raceNew',
    'affiliation',
    'ror_affname',
    'ror_id',  
    'ror_afftype',
    'us_state', 
    'ror_country'
]

# %%
df_small_product = df_small_race_predicted[cols_to_keep]

# %%
col_renamer = {
    'raceNew': 'race'
}

# %%
df_small_product.rename(columns = col_renamer).to_csv(
    '../data/interim/df_small_product.csv', index = False)

# %% [markdown]
# ### Data dictionary
#
# - doi: DOI
# - url: paper URL
# - title: paper title
# - journal: journal
# - authorName: author full name
# - gscholarLink: the link to searching that author's name on Google Scholar
# - firstName: author first name
# - gender: the gender result produced by genderize.io
# - gender_prob: the probability that this guess is correct, genderize.io
# - gender_basedon: how many samples are based on to have this result, genderize.io
# - genderAgree: whether this gender prediction is the same as that produced by gender api (in the following columns)
# - gender_api: the gender prediction by gender api
# - gender_accu: the probability that this guess is correct, gender api
# - gender_samples: how many samples are based on to have this result, genderize.io
# - lastName: author last name
# - race: race prediction based on US census 2010
# - affiliation: author affiliation as shown on journal website
# - ror_id: ror id for the predicted affiliation name
# - ror_affname: predicted affiliation name
# - ror_afftype: affiliation type
# - us_state: the us state where this affiliation is located
# - ror_country: the country where this affiliation is located
