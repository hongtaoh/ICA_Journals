# %% [markdown]
# ## Aim
#
# This notebooks recreates the script to scrape the author data.

# %%
import sys
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import random
import time 
import requests
import re
import json

# %%
ICA_PAPER_DF = '../data/interim/ica_paper_df.csv'
ICA_AUTHOR_DF = 'ica_author_df.csv'
ICA_ERROR_URLS = 'ica_error_urls'

# %%
ica_papers = pd.read_csv(ICA_PAPER_DF)

# %%
ica_papers.shape
# Out:
# (7708, 14)

# %%
# Are urls unique? Yes
len(list(ica_papers.url))
# Out:
# 7708

# %%
# extract useful info
paper_urls = ica_papers.url.tolist()
paper_dois = ica_papers.doi.tolist()
years = ica_papers.year.tolist()
journals = ica_papers.journal.tolist()
titles = ica_papers.title.tolist()

# dics
url_doi_dic = dict(zip(paper_urls, paper_dois))
url_year_dic = dict(zip(paper_urls, years))
url_title_dic = dict(zip(paper_urls, titles))
url_journal_dic = dict(zip(paper_urls, journals))

# initiate data tuples
author_data_tuples = []

# %%
def get_soup(url, idx):
    headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36" \
    "(KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
    }
    response = requests.get(url=url, headers=headers)
    while response.status_code != 200:
        time.sleep(1)
        print(f"{idx} : {url} status code is {response.status_code}, retrying ...")
        response = requests.get(url=url, headers=headers)
    html = response.text 
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def update_author_data(url, soup, author_data_tuples):
    doi = url_doi_dic[url]
    journal = url_journal_dic[url]
    title = url_title_dic[url]
    year = url_year_dic[url]
    # this return a list
    # sometimes there is no authors: https://academic.oup.com/joc/article/33/4/20/4282700
    try:
        authors = soup.find(class_="al-authors-list").find_all(
            class_="al-author-name-more js-flyout-wrap")
        author_num = len(authors)
        for author in authors:
            author_position = authors.index(author) + 1
            '''author names
            '''
            try:
                fullname = author.find(class_="info-card-name").text.strip()
                fullname_split = fullname.split(' ')
                lastname = fullname_split[-1]
                if fullname_split:
                    if len(fullname_split) == 2:
                        firstname = fullname_split[0]
                    # e.g., "M. J. Clarke"
                    elif len(fullname_split) > 2 and len(fullname_split[0]) <= 2 and len(fullname_split[1]) <= 2:
                        firstname = fullname_split[0]
                    # e.g., "M. Jennifer Clarke"
                    elif len(fullname_split) > 2 and len(fullname_split[0]) <= 2 and len(fullname_split[1]) > 2:
                        firstname = fullname_split[1]
                    # g.g., "Mike John Clarke"
                    elif len(fullname_split) > 2 and len(fullname_split[0]) > 2:
                        firstname = fullname_split[0]
                    else:
                        firstname = 'ERROR!'
            except:
                fullname = np.nan
                lastname = np.nan 
                firstname = np.nan
            '''author affiliations
            '''
            try:
                aff = author.find(class_="aff")
#                 sometimes, there is no 'span': 
#                 https://academic.oup.com/ccc/article/15/2/269/6561482
                if aff.find('span') is not None:
                    aff.find('span').extract()
                aff = aff.text.strip()
            except:
                aff = np.nan
            '''author correspondence
            '''
            try:
                cor = author.find(class_="info-author-correspondence").text.strip()
            except:
                cor = np.nan
            '''google scholar link
            '''
            try:
                gscholar_link = author.find(
                    class_="info-card-search info-card-search-google").find('a')['href']
            except:
                gscholar_link = np.nan
            '''update data tuples
            '''
            author_data_tuples.append((
                doi, url, journal, title, year,
                author_num, author_position, fullname,
                firstname, lastname, aff, cor, gscholar_link
            ))
    except:
        author_data_tuples.append((
            doi, url, journal, title, year
        ))
        print(f'{url}')
    return author_data_tuples

# %%
# soup = get_soup('https://academic.oup.com/ccc/article/15/2/269/6561482',1)

# %%
# update_author_data(url, soup, author_data_tuples)
# Out:
# [('10.1111/j.1460-2466.1977.tb01850.x',
#   'https://academic.oup.com/joc/article/27/2/211/4553980',
#   'Journal of Communication',
#   'News vs. “a picture of reality”',
#   '1977',
#   1,
#   1,
#   'Myria Georgiou',
#   'Myria',
#   'Georgiou',
#   'Department of Media and Communications, London School of Economics and Political Science, Houghton Street, London WC2A 2AE, UK',
#   'e-mail: m.a.georgiou@lse.ac.uk.',
#   'http://scholar.google.com/scholar?q=author:%22Georgiou Myria%22'),
#  ('10.1111/j.1460-2466.1977.tb01850.x',
#   'https://academic.oup.com/joc/article/27/2/211/4553980',
#   'Journal of Communication',
#   'News vs. “a picture of reality”',
#   '1977',
#   1,
#   1,
#   'Myria Georgiou',
#   'Myria',
#   'Georgiou',
#   'Department of Media and Communications, London School of Economics and Political Science, Houghton Street, London WC2A 2AE, UK',
#   'e-mail: m.a.georgiou@lse.ac.uk.',
#   'http://scholar.google.com/scholar?q=author:%22Georgiou Myria%22')]

# %%
if __name__ == '__main__':
    # read data
    ica_papers = pd.read_csv(ICA_PAPER_DF)
    
    # extract useful info
    paper_urls = ica_papers.url.tolist()
    paper_dois = ica_papers.doi.tolist()
    years = ica_papers.year.tolist()
    journals = ica_papers.journal.tolist()
    titles = ica_papers.title.tolist()
    
    # dics
    url_doi_dic = dict(zip(paper_urls, paper_dois))
    url_year_dic = dict(zip(paper_urls, years))
    url_title_dic = dict(zip(paper_urls, titles))
    url_journal_dic = dict(zip(paper_urls, journals))
    
    # initiate data tuples
    author_data_tuples = []

    total_urls = len(paper_urls)
    print(f'Total number of URLs to crawl: {total_urls}')
    
    random_paper_urls = random.sample(paper_urls, 10)

    for url in random_paper_urls:
        idx = random_paper_urls.index(url) + 1
#     for url in paper_urls:
#         idx = paper_urls.index(url) + 1
        soup = get_soup(url, idx)
        update_author_data(url, soup, author_data_tuples)
        print(f'{idx} is done')
        time.sleep(0.5 + random.uniform(0, 0.4))
    
    # build dataframe
    author_df = pd.DataFrame(author_data_tuples, columns=[
        'doi',
        'url',
        'journal',
        'title',
        'year',
        'numberOfAuthros',
        'authorPosition',
        'fullname',
        'firstname',
        'lastname',
        'affiliation',
        'correspondence',
        'googleScholarLink'
    ])
    
    author_df.to_csv(ICA_AUTHOR_DF, index=False)
# Out:
# Total number of URLs to crawl: 7708
# 1 is done
# 2 is done
# 3 is done
# 4 is done
# 5 is done
# 6 is done
# 7 is done
# 8 is done
# 9 is done
# https://academic.oup.com/joc/article/27/2/211/4553980
# 10 is done

# %%
author_df
# Out:
#                                    doi  \
# 0   10.1111/j.1468-2958.1976.tb00485.x
# 1   10.1111/j.1468-2958.1976.tb00485.x
# 2   10.1111/j.1468-2958.1976.tb00485.x
# 3                   10.1093/joc/jqx021
# 4   10.1111/j.1460-2466.1978.tb01675.x
# 5   10.1111/j.1460-2466.1992.tb00789.x
# 6   10.1111/j.1468-2958.2004.tb00729.x
# 7   10.1111/j.1468-2958.2004.tb00729.x
# 8   10.1111/j.1468-2958.2004.tb00729.x
# 9   10.1111/j.1468-2958.2004.tb00729.x
# 10  10.1111/j.1468-2958.2004.tb00729.x
# 11  10.1111/j.1468-2958.1996.tb00379.x
# 12  10.1111/j.1460-2466.1974.tb00416.x
# 13  10.1111/j.1460-2466.1974.tb00416.x
# 14  10.1111/j.1460-2466.1982.tb02523.x
# 15  10.1111/j.1468-2958.1984.tb00034.x
# 16  10.1111/j.1468-2958.1984.tb00034.x
# 17  10.1111/j.1460-2466.1977.tb01850.x
#
#                                                   url  \
# 0   https://academic.oup.com/hcr/article/2/3/262/4...
# 1   https://academic.oup.com/hcr/article/2/3/262/4...
# 2   https://academic.oup.com/hcr/article/2/3/262/4...
# 3   https://academic.oup.com/joc/article/68/2/233/...
# 4   https://academic.oup.com/joc/article/28/4/225/...
# 5   https://academic.oup.com/joc/article/42/2/163/...
# 6   https://academic.oup.com/hcr/article/30/2/153/...
# 7   https://academic.oup.com/hcr/article/30/2/153/...
# 8   https://academic.oup.com/hcr/article/30/2/153/...
# 9   https://academic.oup.com/hcr/article/30/2/153/...
# 10  https://academic.oup.com/hcr/article/30/2/153/...
# 11  https://academic.oup.com/hcr/article/22/4/563/...
# 12  https://academic.oup.com/joc/article/24/4/113/...
# 13  https://academic.oup.com/joc/article/24/4/113/...
# 14  https://academic.oup.com/joc/article/32/4/103/...
# 15  https://academic.oup.com/hcr/article/10/4/601/...
# 16  https://academic.oup.com/hcr/article/10/4/601/...
# 17  https://academic.oup.com/joc/article/27/2/211/...
#
#                          journal  \
# 0   Human Communication Research
# 1   Human Communication Research
# 2   Human Communication Research
# 3       Journal of Communication
# 4       Journal of Communication
# 5       Journal of Communication
# 6   Human Communication Research
# 7   Human Communication Research
# 8   Human Communication Research
# 9   Human Communication Research
# 10  Human Communication Research
# 11  Human Communication Research
# 12      Journal of Communication
# 13      Journal of Communication
# 14      Journal of Communication
# 15  Human Communication Research
# 16  Human Communication Research
# 17      Journal of Communication
#
#                                                 title  year  numberOfAuthros  \
# 0   Medium of Communication, Differential Power, a...  1976              3.0
# 1   Medium of Communication, Differential Power, a...  1976              3.0
# 2   Medium of Communication, Differential Power, a...  1976              3.0
# 3   Cultural Voyeurism: A New Framework for Unders...  2018              1.0
# 4                                      A palpable hit  1978              1.0
# 5                    The History of the Public Sphere  1992              1.0
# 6   Is Psychopathology the Key to Understanding Wh...  2004              5.0
# 7   Is Psychopathology the Key to Understanding Wh...  2004              5.0
# 8   Is Psychopathology the Key to Understanding Wh...  2004              5.0
# 9   Is Psychopathology the Key to Understanding Wh...  2004              5.0
# 10  Is Psychopathology the Key to Understanding Wh...  2004              5.0
# 11  The Evaluative Use of Citation Analysis for Co...  1996              1.0
# 12  Children's TV Commercials: The Vanishing Polic...  1974              2.0
# 13  Children's TV Commercials: The Vanishing Polic...  1974              2.0
# 14  Public Information and “Electronic Publishing”...  1982              1.0
# 15  Nonverbal and Relational Communication Associa...  1984              2.0
# 16  Nonverbal and Relational Communication Associa...  1984              2.0
# 17                    News vs. “a picture of reality”  1977              NaN
#
#     authorPosition                  fullname firstname    lastname  \
# 0              1.0         Allen A. Turnbull     Allen    Turnbull
# 1              2.0          Lloyd Strickland     Lloyd  Strickland
# 2              3.0           Kelly G. Shaver     Kelly      Shaver
# 3              1.0               Osei Appiah      Osei      Appiah
# 4              1.0             Marc U. Porat      Marc       Porat
# 5              1.0               John Nerone      John      Nerone
# 6              1.0                Tom Grimes       Tom      Grimes
# 7              2.0               Lori Bergen      Lori      Bergen
# 8              3.0            Kathie Nichols    Kathie     Nichols
# 9              4.0             Eric Vernberg      Eric    Vernberg
# 10             5.0              Peter Fonagy     Peter      Fonagy
# 11             1.0  Edward Truman Funkhouser    Edward  Funkhouser
# 12             1.0         William H. Melody   William      Melody
# 13             2.0             Wendy Ehrlich     Wendy     Ehrlich
# 14             1.0          Kenneth Robinson   Kenneth    Robinson
# 15             1.0          Judee K. Burgoon     Judee     Burgoon
# 16             2.0          Randall J. Koper   Randall       Koper
# 17             NaN                      None      None        None
#
#                                           affiliation  \
# 0                    1Randolph-Mac on Woman’s College
# 1                                2Carleton University
# 2                        3College of William and Mary
# 3   School of Communication, The Ohio State Univer...
# 4                                    1Aspen Institute
# 5         1University of Illinois at Urbana-Champaign
# 6                            1Kansas State University
# 7                            1Kansas State University
# 8                                   2Menninger Clinic
# 9                           3The University of Kansas
# 10                              4University of London
# 11  1Edward Truman Funkhouser (Ph.D., Ohio Univers...
# 12  1William H. Melody is Associate Professor of C...
# 13  2Wendy Ehrlich holds a master's degree from th...
# 14  1Kenneth Robinson is Policy Adviser to the Ass...
# 15  1Judee Burgoon (Ed. D., West Virginia Universi...
# 16  2Randall Koper is a doctoral student in commun...
# 17                                               None
#
#                                        correspondence  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Corresponding author: Osei Appiah, Professor a...
# 4                                                 NaN
# 5                                                 NaN
# 6   5Tom Grimes, Journalism & Mass Communication, ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                               None
#
#                                     googleScholarLink
# 0   http://scholar.google.com/scholar?q=author:%22...
# 1   http://scholar.google.com/scholar?q=author:%22...
# 2   http://scholar.google.com/scholar?q=author:%22...
# 3   http://scholar.google.com/scholar?q=author:%22...
# 4   http://scholar.google.com/scholar?q=author:%22...
# 5   http://scholar.google.com/scholar?q=author:%22...
# 6   http://scholar.google.com/scholar?q=author:%22...
# 7   http://scholar.google.com/scholar?q=author:%22...
# 8   http://scholar.google.com/scholar?q=author:%22...
# 9   http://scholar.google.com/scholar?q=author:%22...
# 10  http://scholar.google.com/scholar?q=author:%22...
# 11  http://scholar.google.com/scholar?q=author:%22...
# 12  http://scholar.google.com/scholar?q=author:%22...
# 13  http://scholar.google.com/scholar?q=author:%22...
# 14  http://scholar.google.com/scholar?q=author:%22...
# 15  http://scholar.google.com/scholar?q=author:%22...
# 16  http://scholar.google.com/scholar?q=author:%22...
# 17                                               None
