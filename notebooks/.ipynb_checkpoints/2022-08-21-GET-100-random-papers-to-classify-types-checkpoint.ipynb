# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('../data/interim/ica_paper_df.csv')

# %%
df.head()
# Out:
#                     journal  \
# 0  Journal of Communication
# 1  Journal of Communication
# 2  Journal of Communication
# 3  Journal of Communication
# 4  Journal of Communication
#
#                                                   issueURL     volumn  \
# 0  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 1  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 2  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 3  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 4  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
#
#      issue                          issueText month  year  category  \
# 0  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 1  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 2  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 3  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# ...

# %%
df.shape
# Out:
# (7708, 14)

# %%
cat = pd.read_csv('../data/interim/cat_class_raw.csv')

# %%
to_exclude_cat = cat[cat.TO_EXCLUDE == True].cat

# %%
df_new = df[~df.category.isin(to_exclude_cat)]
df_new.head()
# Out:
#                     journal  \
# 0  Journal of Communication
# 1  Journal of Communication
# 2  Journal of Communication
# 3  Journal of Communication
# 4  Journal of Communication
#
#                                                   issueURL     volumn  \
# 0  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 1  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 2  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 3  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
# 4  https://academic.oup.com/joc/issue/72/3?browseBy=volume  Volume 72
#
#      issue                          issueText month  year  category  \
# 0  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 1  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 2  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# 3  Issue 3  Issue 3, June 2022, Pages 297–449  June  2022  Articles
# ...

# %%
df_new.sample(100, random_state = 100).to_csv('to_practice_article_class.csv', index=False)

# %%
df_new[df_new.title == 'Intercom']
# Out:
#                        journal  \
# 1836  Journal of Communication
# 1847  Journal of Communication
# 1854  Journal of Communication
# 1971  Journal of Communication
# 1983  Journal of Communication
# 1992  Journal of Communication
# 2005  Journal of Communication
# 2188  Journal of Communication
# 2228  Journal of Communication
# 2243  Journal of Communication
# 2851  Journal of Communication
# 2878  Journal of Communication
# 2915  Journal of Communication
# 2946  Journal of Communication
# 3205  Journal of Communication
# 3226  Journal of Communication
# 3244  Journal of Communication
# 3264  Journal of Communication
#
#                                                      issueURL     volumn  \
# 1836  https://academic.oup.com/joc/issue/41/4?browseBy=volume  Volume 41
# 1847  https://academic.oup.com/joc/issue/41/3?browseBy=volume  Volume 41
# 1854  https://academic.oup.com/joc/issue/41/2?browseBy=volume  Volume 41
# ...

# %%
df_new[df_new.title.str.contains('Corrigendum')]
# Out:
#                                          journal  \
# 4196                Human Communication Research
# 6307  Journal of Computer-Mediated Communication
# 7297         Communication, Culture and Critique
#
#                                                       issueURL     volumn  \
# 4196   https://academic.oup.com/hcr/issue/46/1?browseBy=volume  Volume 46
# 6307  https://academic.oup.com/jcmc/issue/23/4?browseBy=volume  Volume 23
# 7297   https://academic.oup.com/ccc/issue/12/3?browseBy=volume  Volume 12
#
#         issue                               issueText      month  year  \
# 4196  Issue 1      Issue 1, January 2020, Pages 1–112    January  2020
# 6307  Issue 4       Issue 4, July 2018, Pages 181–243       July  2018
# 7297  Issue 3  Issue 3, September 2019, Pages 305–434  September  2019
#
#                category  \
# 4196  Original Articles
# 6307  Research Articles
# 7297           Articles
#
# ...

# %%
df_new[df_new.title == 'Communication Films']
# Out:
#                        journal  \
# 3569  Journal of Communication
# 3580  Journal of Communication
# 3589  Journal of Communication
# 3609  Journal of Communication
# 3632  Journal of Communication
# 3664  Journal of Communication
# 3678  Journal of Communication
# 3687  Journal of Communication
# 3696  Journal of Communication
# 3705  Journal of Communication
# 3715  Journal of Communication
# 3727  Journal of Communication
# 3748  Journal of Communication
# 3768  Journal of Communication
#
#                                                      issueURL     volumn  \
# 3569  https://academic.oup.com/joc/issue/16/3?browseBy=volume  Volume 16
# 3580  https://academic.oup.com/joc/issue/16/2?browseBy=volume  Volume 16
# 3589  https://academic.oup.com/joc/issue/16/1?browseBy=volume  Volume 16
# 3609  https://academic.oup.com/joc/issue/15/2?browseBy=volume  Volume 15
# 3632  https://academic.oup.com/joc/issue/14/3?browseBy=volume  Volume 14
# ...

# %%
df_new[df_new.title.str.contains('Erratum')]
# Out:
#                                          journal  \
# 197                     Journal of Communication
# 4191                Human Communication Research
# 4402                Human Communication Research
# 6275  Journal of Computer-Mediated Communication
# 6294  Journal of Computer-Mediated Communication
# 7646         Communication, Culture and Critique
#
#                                                        issueURL     volumn  \
# 197     https://academic.oup.com/joc/issue/68/4?browseBy=volume  Volume 68
# 4191  https://academic.oup.com/hcr/issue/46/2-3?browseBy=volume  Volume 46
# 4402    https://academic.oup.com/hcr/issue/37/3?browseBy=volume  Volume 37
# 6275   https://academic.oup.com/jcmc/issue/24/6?browseBy=volume  Volume 24
# 6294   https://academic.oup.com/jcmc/issue/24/1?browseBy=volume  Volume 24
# 7646     https://academic.oup.com/ccc/issue/3/1?browseBy=volume   Volume 3
#
#           issue                                  issueText       month  year  \
# ...
