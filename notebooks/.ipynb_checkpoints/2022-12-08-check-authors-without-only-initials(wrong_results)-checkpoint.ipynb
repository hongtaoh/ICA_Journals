# %% [markdown]
# ## AIM
#
# With this notebook, I aim to
#  - Find authors without full name
#  - find authors with first names being initials
#
# ### Note
#
# On 2022-12-09, I found that this is incorrect. I should use `pd.concat([one_df, two_df])` rather than `isin(to_remove_dois)`.

# %%
import pandas as pd
from collections import Counter
import numpy as np

# %%
# df1 = pd.read_csv('../data/processed/author_with_pred.csv')
# df1[(df1.firstName.isnull()) | (df1.lastName.isnull())].doi

# %%
df = pd.read_csv('../data/processed/authors_to_study.csv')

# %%
df[(df.firstName.isnull()) | (df.lastName.isnull())]
# Out:
#                                     authorID  \
# 3612  10.1111/j.1460-2466.1980.tb02015.x+2.0
#
#                                      doi  \
# 3612  10.1111/j.1460-2466.1980.tb02015.x
#
#                                                     url  year  \
# 3612  https://academic.oup.com/joc/article/30/4/50/4...  1980
#
#                                          title                   journal  \
# 3612  Programming for Development in Indonesia  Journal of Communication
#
#       numberOfAuthors  authorPosition authorFullName firstName  ...     white  \
# 3612              2.0             2.0         Alfian       NaN  ...  0.220853
#
#      raceHighest raceSecondHighest  raceDiff  \
# 3612    0.684015          0.220853  0.463161
#
#                                            affProcessed  \
# 3612  national institute of economic and social rese...
#
#                                           affiliation.2  \
# 3612  2 National Institute of Economic and Social Re...
#
#                                             ROR_AFFNAME matchMethod  \
# 3612  National Institute of Economic and Social Rese...       Exact
#
#                          ROR_ID type
# 3612  https://ror.org/048m81442    R
#
# [1 rows x 39 columns]

# %% [markdown]
# There is only one person whose name is not complete.

# %%
df = df[(df.firstName.notnull()) & (df.lastName.notnull())]

# %%
df['firstNameLength'] = df.apply(lambda row: len(row.firstName), axis = 1)

# %%
two_df = df[(df.firstName.str.contains('.', regex = False)) & (df.firstNameLength == 2)]
two_df.sample(3)
# Out:
#                                     authorID  \
# 3409  10.1111/j.1460-2466.1982.tb02515.x+1.0
# 6522  10.1111/j.1468-2958.1996.tb00376.x+1.0
# 3776  10.1111/j.1460-2466.1979.tb01710.x+3.0
#
#                                      doi  \
# 3409  10.1111/j.1460-2466.1982.tb02515.x
# 6522  10.1111/j.1468-2958.1996.tb00376.x
# 3776  10.1111/j.1460-2466.1979.tb01710.x
#
#                                                     url  year  \
# 3409  https://academic.oup.com/joc/article/32/4/22/4...  1982
# 6522  https://academic.oup.com/hcr/article/22/4/482/...  1996
# 3776  https://academic.oup.com/joc/article/29/3/42/4...  1979
#
#                                                   title  \
# 3409   Glued to the Box?: Patterns of TV Repeat-Viewing
# 6522  Psychological Processes Underlying Cultivation...
# 3776  Atrocity Tales, the Unification Church, and th...
#
#                            journal  numberOfAuthors  authorPosition  \
# 3409      Journal of Communication              3.0             1.0
# 6522  Human Communication Research              1.0             1.0
# 3776      Journal of Communication              3.0             3.0
#
#          authorFullName firstName  ... raceHighest raceSecondHighest  \
# 3409      T. P. Barwise        T.  ...    0.895544          0.060819
# 6522        L. J. Shrum        L.  ...    0.889826          0.060513
# 3776  J. C. Ventimiglia        J.  ...    0.953322          0.026924
#
#       raceDiff                                       affProcessed  \
# 3409  0.834725  t p barwise is senior research officer at the ...
# 6522  0.829313  l j shrum is an assistant professor in the dep...
# 3776  0.926398  assistant professor all in the department of s...
#
#                                           affiliation.2  \
# 3409  1 T. P. Barwise is Senior Research Officer at ...
# 6522  1 L. J. Shrum (Ph.D., University of Illinois a...
# 3776  1 Assistant Professor, all in the Department o...
#
#                                ROR_AFFNAME  matchMethod  \
# 3409                London Business School        Exact
# 6522     University of Business in Wrocław    API_QUERY
# 3776  The University of Texas at Arlington        Exact
#
#                          ROR_ID type firstNameLength
# 3409  https://ror.org/001c2sn75    R               2
# 6522  https://ror.org/04qxzae03    R               2
# 3776  https://ror.org/019kgqr73    R               2
#
# [3 rows x 40 columns]

# %%
two_df_doi = two_df.doi.tolist()

# %%
one_df_doi = df[df.firstNameLength == 1].doi.tolist()

# %%
## THIS IS WRONG!
to_remove_dois = list(set(two_df_doi + one_df_doi))
len(to_remove_dois)
# Out:
# 70
