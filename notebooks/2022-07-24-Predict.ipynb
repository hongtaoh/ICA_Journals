# %%
import pandas as pd
import requests
import numpy as np
import re
from collections import Counter
import random

# %%
race_pred = pd.read_csv('../data/interim/author_with_pred.csv')
race_pred.shape
# Out:
# (13603, 25)

# %%
race_pred.head(2)
# Out:
#                    doi                                                    url  \
# 0  10.1093/joc/jqac004  https://academic.oup.com/joc/article/72/3/297/6529454
# 1  10.1093/joc/jqac004  https://academic.oup.com/joc/article/72/3/297/6529454
#
#    year  \
# 0  2022
# 1  2022
#
#                                                                                                 title  \
# 0  The Gender Divide in Wikipedia: Quantifying and Assessing the Impact of Two Feminist Interventions
# 1  The Gender Divide in Wikipedia: Quantifying and Assessing the Impact of Two Feminist Interventions
#
#                     journal datePublished          authorFullName firstName  \
# 0  Journal of Communication    2022-02-16       Isabelle Langrock  Isabelle
# 1  Journal of Communication    2022-02-16  Sandra González-Bailón    Sandra
#
#           lastName  numberOfAuthors  authorPosition  \
# 0         Langrock              2.0             1.0
# 1  González-Bailón              2.0             2.0
#
#                                                                                      affiliation  \
# 0  Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
# 1  Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
#
#   genderize  genderize_prob  genderize_basedon genderAccuracy       api  \
# 0    female            0.99            89728.0           High  0.007762
# 1    female            0.98           266121.0           High  0.010406
#
#       black  hispanic     white      race  raceHighest  raceSecondHighest  \
# 0  0.066429  0.030049  0.895760     white     0.895760           0.066429
# 1  0.000300  0.979183  0.010111  hispanic     0.979183           0.010406
#
#    raceDiff racePredAccuracy
# 0  0.829331             High
# 1  0.968777             High

# %% [markdown]
# ## Affiliations

# %%
def notNaN(num):
    return num == num

# %%
notNaN(1)
# Out:
# True

# %%
def process_affiliation_text(aff):
    if notNaN(aff):
        aff = aff.lower()
        # remove anything other than characters
        aff = re.sub('[^a-z ]+', ' ', aff)
        aff = ' '.join(aff.split())
        # delete anything between ()
        aff = re.sub(r'\([^)]*\)', '', aff)
        return aff
    else:
        return np.nan

# %%
random_aff = random.choice(race_pred.affiliation)
random_aff
# Out:
# '1 School of Information and Library Science and Department of Sociology, University of North Carolina at Chapel Hill, Chapel Hill, NC 27516, USA'

# %%
process_affiliation_text(random_aff)
# Out:
# 'school of information and library science and department of sociology university of north carolina at chapel hill chapel hill nc usa'

# %%
race_pred['affProcessed'] = [process_affiliation_text(aff) for aff in race_pred.affiliation]

# %%
race_pred.head(1)
# Out:
#                    doi                                                    url  \
# 0  10.1093/joc/jqac004  https://academic.oup.com/joc/article/72/3/297/6529454
#
#    year  \
# 0  2022
#
#                                                                                                 title  \
# 0  The Gender Divide in Wikipedia: Quantifying and Assessing the Impact of Two Feminist Interventions
#
#                     journal datePublished     authorFullName firstName  \
# 0  Journal of Communication    2022-02-16  Isabelle Langrock  Isabelle
#
#    lastName  numberOfAuthors  authorPosition  \
# 0  Langrock              2.0             1.0
#
#                                                                                      affiliation  \
# 0  Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA
#
#   genderize  genderize_prob  genderize_basedon genderAccuracy       api  \
# 0    female            0.99            89728.0           High  0.007762
#
#       black  hispanic    white   race  raceHighest  raceSecondHighest  \
# 0  0.066429  0.030049  0.89576  white      0.89576           0.066429
#
#    raceDiff racePredAccuracy  \
# 0  0.829331             High
#
#                                                                         affProcessed
# 0  annenberg school for communication university of pennsylvania philadelphia pa usa

# %%
affs = race_pred.affProcessed
# deduplicate
affs = list(set(affs))
# remove nan
affs = [x for x in affs if str(x) != 'nan']
len(affs)
# Out:
# 8443

# %%
# affs = [aff.lower() for aff in affs]
# # delete anything between ()
# affs = [re.sub(r'\([^)]*\)', '', aff) for aff in affs]
# # delete the number at the start of the string
# affs = [re.sub(r"^[0-9]*\.?[0-9]+", '', aff) for aff in affs]
# affs = [aff.strip() for aff in affs]

# %%
affs[1:5]
# Out:
# ['chairman of speech correction university of georgia athens georgia',
#  'associate professor in the department of communication miami university oxford oh james b stiff is an associate professor in the department of communication arizona state university tempe az',
#  'mr kauffman is the director of research at hawthorn center',
#  'department of journalism media and communication university of gothenburg seminariegatan b gothenburg sweden']

# %% [markdown]
# ### ROR datasets

# %% [markdown]
# ROR Data and build a dictionary

# %%
import json

# %%
with open('../data/raw/large/ror.json', 'r') as myfile:
    data=myfile.read()
data = json.loads(data)

# %%
ror_name_id_dic = {}
for i in data:
    affname = i['name'].lower()
    ror_name_id_dic[affname] = i['id']

# %%
# ror_name_id_dic

# %%
data[0]
# Out:
# {'id': 'https://ror.org/019wvm592',
#  'name': 'Australian National University',
#  'types': ['Education'],
#  'links': ['http://www.anu.edu.au/'],
#  'aliases': [],
#  'acronyms': ['ANU'],
#  'status': 'active',
#  'wikipedia_url': 'http://en.wikipedia.org/wiki/Australian_National_University',
#  'labels': [],
#  'email_address': None,
#  'ip_addresses': [],
#  'established': 1946,
#  'country': {'country_code': 'AU', 'country_name': 'Australia'},
#  'relationships': [{'type': 'Related',
#    'label': 'Calvary Hospital',
#    'id': 'https://ror.org/041c7s516'},
#   {'type': 'Related',
#    'label': 'Canberra Hospital',
#    'id': 'https://ror.org/04h7nbn38'},
#   {'type': 'Related',
#    'label': 'Goulburn Base Hospital',
#    'id': 'https://ror.org/030jpqj15'},
#   {'type': 'Child',
#    'label': 'ARC Centre of Excellence for Transformative Meta-Optical Systems',
#    'id': 'https://ror.org/05sh7tb37'},
#   {'type': 'Child',
#    'label': 'ARC Centre of Excellence in Plant Energy Biology',
#    'id': 'https://ror.org/01a1mq059'},
#   {'type': 'Child',
#    'label': 'Mount Stromlo Observatory',
#    'id': 'https://ror.org/006a4jj40'}],
#  'addresses': [{'line': None,
#    'lat': -35.2778,
#    'lng': 149.1205,
#    'postcode': None,
#    'primary': False,
#    'city': 'Canberra',
#    'state': 'Australian Capital Territory',
#    'state_code': 'AU-ACT',
#    'country_geonames_id': 2077456,
#    'geonames_city': {'id': 2172517,
#     'city': 'Canberra',
#     'nuts_level1': {'code': None, 'name': None},
#     'nuts_level2': {'code': None, 'name': None},
#     'nuts_level3': {'code': None, 'name': None},
#     'geonames_admin1': {'id': 2177478,
#      'name': 'ACT',
#      'ascii_name': 'ACT',
#      'code': 'AU.01'},
#     'geonames_admin2': {'id': None,
#      'name': None,
#      'ascii_name': None,
#      'code': None},
#     'license': {'attribution': 'Data from geonames.org under a CC-BY 3.0 license',
#      'license': 'http://creativecommons.org/licenses/by/3.0/'}}}],
#  'external_ids': {'ISNI': {'preferred': None, 'all': ['0000 0001 2180 7477']},
#   'FundRef': {'preferred': '501100000995',
#    'all': ['501100000995', '501100001151', '100009020']},
#   'OrgRef': {'preferred': None, 'all': ['285106']},
#   'Wikidata': {'preferred': None, 'all': ['Q127990']},
#   'GRID': {'preferred': 'grid.1001.0', 'all': 'grid.1001.0'}}}

# %%
target_str = ['university', 
              'school',
              'college', 
              "universität", 
              "université", 
              "inc.", 
              "company", 
              'coorporation',
              'institute',
              'center',
              'centre',
             ]

# %%
ror_affnames = []
for i in data:
    affname = i['name'].lower()
    if any(x in affname for x in target_str):
        ror_affnames.append(affname)
ror_affnames.remove('he university')
ror_affnames.remove('french institute for research in computer science and automation')
ror_affnames.remove('australian national university')
ror_affnames.remove('monash university')

# %%
len(ror_affnames)
# Out:
# 29820

# %%
ror_affnames[455:460]
# Out:
# ['national autonomous university of mexico',
#  'national university of la plata',
#  'heriot-watt university',
#  'university of the balearic islands',
#  'reykjavík university']

# %% [markdown]
# I concluded that it's better to use absolute match first before I use fuzzy match

# %%
matched_dic = {}
matched = 0
failed = 0
failed_list = []
for aff in affs:
    for x in ror_affnames:
        if x in aff:
            matched += 1
            matched_dic[aff] = x
            break

# %%
len(affs)
# Out:
# 8443

# %%
matched
# Out:
# 6102

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.DataFrame(matched_dic.items()).sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# 2775                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       assistant professor of sociology at ohio state university and research fellow in the department of social relations at johns hopkins university
# 2484                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     francis balle is professor at the university of paris director of the french press institute and co editor of the cahiers de la communication idalina cappe de baillon received a master s degree from the french press institute
# 3253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    graduate school of culture technology korea advanced institute of science and technology daejeon republic of korea
# 3504                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        department of communication university of washington at seattle seattle wa usa
# 2640                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  associate professor of computer science at virginia tech where she has been since prior to that she was a research staff member and manager at ibm s t j watson research center dr rosson received her phd in from the university of texas at austin
# 3537                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             dr stewart received his degree from michigan state university in and is a former member of its faculty now with the campbell ewald company in detroit he is responsible for research in the sciences and arts pertaining to communication
# 4424                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           harvard t h chan school of public health and dana farber cancer institute brookline avenue lw boston ma usa
# 4734                                                                                                                                                                                     senior academic in information systems at murdoch before taking up a professorship at the school of management at griffith university following his ph d cambridge in his postdoctoral work he developed intelligent and collaborative decision support systems in the financial and defense sectors twice a british council visiting fellow to pr china he has over publications in the field of is emphasizing human knowledge and intelligence in organizational systems his current research involves knowledge management and internet commerce applications
# 4093                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            judee k burgoon is professor of communication at the university of arizona
# 6057  barbara j wilson ph d university of wisconsin madison is assistant professor in the department of communication university of louisville louisville kentucky this research was supported by a grant from the college of arts and sciences university of louisville the author would like to thank mark filbert for serving as one of the experimenters and lesa mcneill for helping with the experimental materials special thanks are due to robert spencer principal of field elementary school and linda duvall director of the klondike lane kinder care learning center for allowing the study tobe conducted in their schools thanks are also due to the teachers staff and studentsat field elementary school and kinder care learning center
#
#                                                        1
# 2775                            johns hopkins university
# 2484                                 university of paris
# 3253  korea advanced institute of science and technology
# 3504                            university of washington
# 2640                   the university of texas at austin
# 3537                           michigan state university
# 4424                                    cancer institute
# 4734                                 griffith university
# 4093                               university of arizona
# 6057                            university of louisville

# %%
list(set(matched_dic.values()))
# Out:
# ['university of new hampshire',
#  'the university of texas at austin',
#  'valdosta state university',
#  'massey university',
#  'stephens college',
#  'wichita state university',
#  'transylvania university',
#  'the university of texas at arlington',
#  'renmin university of china',
#  'singapore university of technology and design',
#  'mcgill university',
#  'muhlenberg college',
#  'acadia university',
#  'university of new mexico',
#  'century university',
#  'loyola university new orleans',
#  'dalian university of technology',
#  'copenhagen business school',
#  'chungnam national university',
#  'eckerd college',
#  'university of the west of scotland',
#  'strayer university',
#  'masaryk university',
#  'yerevan state university',
#  'university of canberra',
#  'city university',
#  'university of leeds',
#  'tulane university',
#  'american university',
#  'university of tartu',
#  'baruch college',
#  'university of kent',
#  'stillman college',
#  'oakland university',
#  'university of south alabama',
#  'school of international relations',
#  'university of oulu',
#  'monmouth university',
#  'university of southern california',
#  'university of puget sound',
#  'wayland baptist university',
#  'hawaii pacific university',
#  'pennsylvania state university',
#  'westmont college',
#  'brown university',
#  'louisiana state university',
#  'trinity university',
#  'university of virginia',
#  'fordham university',
#  'tokai university',
#  'national center for supercomputing applications',
#  'amherst college',
#  'university of adelaide',
#  'hampshire college',
#  'karlstad university',
#  'hanover university of music drama and media',
#  'foundation university',
#  'west chester university',
#  'university of colorado denver',
#  'west virginia university',
#  'baylor university',
#  'methodist university',
#  'tel aviv university',
#  'prince of songkla university',
#  'institute of political science',
#  'university of wolverhampton',
#  'wheeling jesuit university',
#  'california polytechnic state university',
#  'university of alberta',
#  'central michigan university',
#  'university of sheffield',
#  'university of iceland',
#  'university of hong kong',
#  'international christian university',
#  'college of new jersey',
#  'leiden university',
#  'indiana state university',
#  'new college',
#  'montana state university',
#  'national institute of health',
#  'university of northern british columbia',
#  'university of bath',
#  'hofstra university',
#  'london south bank university',
#  'chinese university of hong kong',
#  'swansea university',
#  'university of melbourne',
#  'adelphi university',
#  'rwth aachen university',
#  'university of bremen',
#  'tomsk polytechnic university',
#  'naval postgraduate school',
#  'university of rochester medical center',
#  'university of ibadan',
#  'queensland university of technology',
#  'national institutes of health',
#  'bethel college',
#  'university of pretoria',
#  'clemson university',
#  'fairleigh dickinson university',
#  'ryerson university',
#  'dillard university',
#  'university of miami',
#  'xavier university',
#  'university of connecticut',
#  'national chung cheng university',
#  'makerere university',
#  'la salle university',
#  'young harris college',
#  'university of georgia',
#  'northern new mexico college',
#  'national central university',
#  'sheffield hallam university',
#  'bridgewater college',
#  'missouri western state university',
#  'university of winnipeg',
#  'hadassah academic college',
#  'university of evansville',
#  'coastal carolina university',
#  'stanford university',
#  'university of london',
#  'university of tokyo',
#  'lund university',
#  'catholic university of daegu',
#  'rhodes university',
#  'indonesian institute of sciences',
#  'kanto gakuin university',
#  'university of derby',
#  'trent university',
#  'university of alaska southeast',
#  'university of louisville',
#  'european university viadrina',
#  'east carolina university',
#  'virginia commonwealth university',
#  'elon university',
#  'california institute of technology',
#  'nazareth college',
#  'millsaps college',
#  'college of staten island',
#  'university of nevada reno',
#  'national institute of informatics',
#  'rice university',
#  'netanya academic college',
#  'university of birmingham',
#  'university of waterloo',
#  'university of plymouth',
#  'university of cologne',
#  'kingston university',
#  'friedrich schiller university jena',
#  'leibniz institute for the social sciences',
#  'university of auckland',
#  'western university',
#  'university of milan',
#  'university of bristol',
#  'university of technology',
#  'university of surrey',
#  'gordon college',
#  'university of nebraska at omaha',
#  'case western reserve university',
#  'athens university of economics and business',
#  'york st john university',
#  'jiangsu university',
#  'university of bamberg',
#  'lee university',
#  'arizona state university',
#  'carroll college',
#  'monmouth college',
#  'yangzhou university',
#  'victoria university',
#  'birmingham city university',
#  'university of exeter',
#  'indiana university',
#  'marquette university',
#  'university of tulsa',
#  'university of ljubljana',
#  'aarhus university',
#  'university of barcelona',
#  'southern illinois university edwardsville',
#  'cancer research center',
#  'yale university',
#  'university of tennessee at knoxville',
#  'eastern new mexico university',
#  'college of southern nevada',
#  'missouri state university',
#  'cardiff university',
#  'drake university',
#  'university of aberdeen',
#  'griffith university',
#  'university of hull',
#  'university of toronto',
#  'university west',
#  'shenzhen university',
#  'jawaharlal nehru university',
#  'university of portsmouth',
#  'eindhoven university of technology',
#  'southwest baptist university',
#  'university of gothenburg',
#  'lafayette college',
#  'university of granada',
#  'portland state university',
#  'hangzhou normal university',
#  'wesleyan university',
#  'occidental college',
#  'academic medical center',
#  'loyola marymount university',
#  'university of warwick',
#  'university of north carolina wilmington',
#  'bangalore university',
#  'bellevue college',
#  'the university of texas at el paso',
#  'english and foreign languages university',
#  'central college',
#  'bentley university',
#  'national university',
#  'university of essex',
#  'university of stirling',
#  'kokugakuin university',
#  'center for information technology',
#  'university of mobile',
#  'goshen college',
#  'texas christian university',
#  'university of northern iowa',
#  'university of southern denmark',
#  'university of quebec at montreal',
#  'maimonides medical center',
#  'stockholm school of economics',
#  'university of the aegean',
#  'lansing community college',
#  'kyungnam university',
#  'national university of singapore',
#  'university of trieste',
#  'michigan technological university',
#  'university of pittsburgh',
#  'university of augsburg',
#  'city university of hong kong',
#  'university of cauca',
#  'life university',
#  'boston university',
#  'university of manitoba',
#  'webster vienna private university',
#  'national center for environmental health',
#  'university of trier',
#  'university of north florida',
#  'university of north carolina at charlotte',
#  'ghent university',
#  'brock university',
#  'university of manchester',
#  'suffolk university',
#  'kangwon national university',
#  'johns hopkins university',
#  'cleveland university',
#  'aichi shukutoku university',
#  'utrecht university',
#  'university of urbino',
#  'skidmore college',
#  'college of saint elizabeth',
#  'chapman university',
#  'central connecticut state university',
#  'kwangwoon university',
#  'western illinois university',
#  'pepperdine university',
#  'chinese center for disease control and prevention',
#  'international development research centre',
#  'norwegian university of science and technology',
#  'nihon university',
#  'kookmin university',
#  'dixie state university',
#  'williams college',
#  'university of navarra',
#  'idaho state university',
#  'san diego state university',
#  'university of colorado colorado springs',
#  'georgia state university',
#  'university of the west indies',
#  'cape peninsula university of technology',
#  'university of idaho',
#  'nanyang technological university',
#  'texas tech university',
#  'gonzaga university',
#  'barry university',
#  'liberal arts university',
#  'the ohio state university',
#  'university of konstanz',
#  'bloomsburg university',
#  'pontifical catholic university of rio grande do sul',
#  'university of british columbia',
#  'johannes gutenberg university of mainz',
#  'san jose state university',
#  'allegheny college',
#  'jagiellonian university',
#  'auburn university',
#  'university of wales',
#  'institute for social research',
#  'myongji university',
#  'vytautas magnus university',
#  'bi norwegian business school',
#  'southern illinois university carbondale',
#  'western sydney university',
#  'eastern michigan university',
#  'dublin city university',
#  'institute of sociology',
#  'fontbonne university',
#  'new mexico state university',
#  'quinnipiac university',
#  'american institutes for research',
#  'rikkyo university',
#  'sonoma state university',
#  'university of san diego',
#  'university of victoria',
#  'university of alabama',
#  'latin american institute',
#  'augustana college',
#  'institute for the future',
#  'university of iowa',
#  'roskilde university',
#  'university of nebraska at kearney',
#  'furman university',
#  'southeastern louisiana university',
#  'university of lagos',
#  'morristown medical center',
#  'nhtv breda university of applied sciences',
#  'kadir has university',
#  'national humanities center',
#  'radboud university nijmegen',
#  'university of bordeaux',
#  'northern kentucky university',
#  'university of liverpool',
#  'indian institute of mass communication',
#  'princeton university',
#  'oberlin college',
#  'university of montevallo',
#  'santa barbara city college',
#  'university of salford',
#  'vanderbilt university',
#  'university of fribourg',
#  'stonehill college',
#  'western washington university',
#  'university of north carolina at asheville',
#  'university of wyoming',
#  'robert morris university',
#  'city university of new york',
#  'bowling green state university',
#  'center for drug evaluation and research',
#  'wittenberg university',
#  'university of washington',
#  'university of strathclyde',
#  'university of wollongong',
#  'morgridge institute for research',
#  'university school',
#  'university of montreal',
#  'university of salzburg',
#  'stellenbosch university',
#  'mansfield university',
#  'hanyang university',
#  'national institute of advanced industrial science and technology',
#  'babson college',
#  'george mason university',
#  'moscow state university',
#  'texas college',
#  'macquarie university',
#  'university of western australia',
#  'tufts university',
#  'university of valencia',
#  'hope college',
#  'mount mercy university',
#  'davidson college',
#  'north carolina state university',
#  'university of trento',
#  'university of mary',
#  'governors state university',
#  'vernon college',
#  'university of the western cape',
#  'university of vermont',
#  'emerson college',
#  'regent university',
#  'luther university',
#  'university of salamanca',
#  'university of udine',
#  'memorial university of newfoundland',
#  'dartmouth college',
#  'university of pennsylvania',
#  'chatham university',
#  'bryn mawr college',
#  'villanova university',
#  'university of north carolina at greensboro',
#  'otero junior college',
#  'university of oklahoma',
#  'nanzan university',
#  'chulalongkorn university',
#  'james madison university',
#  'university of colorado boulder',
#  'waseda university',
#  'goethe university frankfurt',
#  'the university of texas medical branch at galveston',
#  'university of east anglia',
#  'university of twente',
#  'minnesota state university moorhead',
#  'rensselaer polytechnic institute',
#  'emory university',
#  'copenhagen university hospital',
#  'university of hartford',
#  'university of queensland',
#  'bridge university',
#  'shanghai university',
#  'university of mississippi',
#  'erasmus university rotterdam',
#  'niagara university',
#  'university of bologna',
#  'chang gung university',
#  'ariel university',
#  'angelo state university',
#  'university of tasmania',
#  'howard university',
#  'university of regina',
#  'institute of child health',
#  'newcastle university',
#  'youngstown state university',
#  'stetson university',
#  'islamic university',
#  'ulsan national institute of science and technology',
#  'brooklyn college',
#  'alfred university',
#  'university of winchester',
#  'university of prince edward island',
#  'providence college',
#  'university of chile',
#  'university of richmond',
#  'marshall university',
#  'university of cambridge',
#  'thomas jefferson university',
#  'rowan university',
#  'university of colombo',
#  'beijing normal university',
#  'loma linda university',
#  'inha university',
#  'wake forest university',
#  'jacobs university',
#  'illinois state university',
#  'bellarmine university',
#  'lancaster university',
#  'bournemouth university',
#  'orange coast college',
#  'michigan state university',
#  'montgomery college',
#  'utah valley university',
#  'university of notre dame',
#  'fudan university',
#  'air university',
#  'university of copenhagen',
#  'senshu university',
#  'macalester college',
#  'university of international business and economics',
#  'baker university',
#  'university of oslo',
#  'kennesaw state university',
#  'university of erfurt',
#  'carleton college',
#  'mercer university',
#  'california state polytechnic university',
#  'kansas state university',
#  'university of alaska fairbanks',
#  'university of denver',
#  'kainan university',
#  'city college',
#  'university of massachusetts boston',
#  'san francisco state university',
#  'lakehead university',
#  'concordia university',
#  'college of wooster',
#  'keele university',
#  'university of the thai chamber of commerce',
#  'bakersfield college',
#  'korea advanced institute of science and technology',
#  'college of the holy cross',
#  'university college london',
#  'university of south florida',
#  'christ university',
#  'san bernardino valley college',
#  'rmit university',
#  'pittsburg state university',
#  'university of alabama at birmingham',
#  'pohang university of science and technology',
#  'university of tampa',
#  'sogang university',
#  'tohoku gakuin university',
#  'tamkang university',
#  'denison university',
#  'georgia institute of technology',
#  'vestfold university college',
#  'depauw university',
#  'rk university',
#  'washburn university',
#  'hankuk university of foreign studies',
#  'zefat academic college',
#  'seoul national university',
#  'university of cincinnati',
#  'aspen institute',
#  'utah state university',
#  'university of north dakota',
#  'mcmaster university',
#  'syracuse university',
#  'middle tennessee state university',
#  'university north',
#  'rhode island school of design',
#  'oklahoma state university',
#  'university of scranton',
#  'la trobe university',
#  'jinan university',
#  'university of saskatchewan',
#  'university of bridgeport',
#  'fox chase cancer center',
#  'pacific university',
#  'university of dubuque',
#  'iona college',
#  'rochester institute of technology',
#  'swinburne university of technology',
#  'jeonju university',
#  'university of delaware',
#  'university of technology sydney',
#  'eastern illinois university',
#  'ursinus college',
#  'austin peay state university',
#  'london business school',
#  'university of turku',
#  'ajou university',
#  'sam houston state university',
#  'towson university',
#  'hallym university',
#  'bowdoin college',
#  'saint louis university',
#  'national chengchi university',
#  'singapore management university',
#  'federal university of bahia',
#  'university of hawaii at hilo',
#  'upsala college',
#  'eastern washington university',
#  'yeshiva university',
#  'wuhan university',
#  'american university of beirut',
#  'university of southern indiana',
#  'coventry university',
#  'university of dayton',
#  'johannes kepler university of linz',
#  'columbia university',
#  'hunter college',
#  'college of business administration',
#  'university of the arts london',
#  'washington state university',
#  'texas state university',
#  'university of geneva',
#  'college of charleston',
#  'aalto university',
#  'middlebury college',
#  'university of montana',
#  'university of missouri',
#  'international university',
#  'drury university',
#  'oregon state university',
#  'hiram college',
#  'loyola university maryland',
#  'lasell college',
#  'florida state university',
#  'university of cape town',
#  'colgate university',
#  'simon fraser university',
#  'trinity college dublin',
#  'butler university',
#  'delft university of technology',
#  'university of zurich',
#  'york university',
#  'university of north alabama',
#  'cyprus university of technology',
#  'loyola university chicago',
#  'peace research institute',
#  'university of giessen',
#  'mary baldwin college',
#  'edith cowan university',
#  'university of guelph',
#  'seton hall university',
#  'university of edinburgh',
#  'aalborg university',
#  'institute of informatics',
#  'jacksonville state university',
#  'creighton university',
#  'northern college',
#  'northeastern university',
#  'florida international university',
#  'yeungnam university',
#  'university of alaska anchorage',
#  'kibbutzim college',
#  'radford university',
#  'illinois institute of technology',
#  'shepherd university',
#  'millikin university',
#  'ocean university of china',
#  'alexandria university',
#  'university of north texas',
#  'university of amsterdam',
#  'county college of morris',
#  'ashkelon academic college',
#  'university of ghana',
#  'university of arkansas at little rock',
#  'central queensland university',
#  'university of freiburg',
#  'george washington university',
#  'university of glasgow',
#  'university of waikato',
#  'salisbury university',
#  'miami university',
#  'ono academic college',
#  'illinois college',
#  'zhejiang university',
#  'university of utah',
#  'university of hyderabad',
#  'john jay college of criminal justice',
#  'city college of new york',
#  'murdoch university',
#  'university of central oklahoma',
#  'liberty university',
#  'max planck institute for the study of religious and ethnic diversity',
#  'pace university',
#  'university of mannheim',
#  'institute for comparative media and communication studies',
#  'boise state university',
#  'ithaca college',
#  'seinan gakuin university',
#  'central european university',
#  'duquesne university',
#  'hong kong baptist university',
#  'pomona college',
#  'catholic university of america',
#  'georgetown university',
#  'siena college',
#  'bowie state university',
#  'university of oxford',
#  'university of north carolina at chapel hill',
#  'university of canterbury',
#  'university of akureyri',
#  'university medical center',
#  'grand valley state university',
#  'new jersey institute of technology',
#  'university of ontario institute of technology',
#  'wayne state university',
#  'university of central lancashire',
#  'university of dallas',
#  'brigham young university',
#  'zayed university',
#  'university city science center',
#  'american national standards institute',
#  'flinders university',
#  'university of maine',
#  'university of akron',
#  'leipzig university',
#  'charles university',
#  'university of south carolina',
#  'purdue university west lafayette',
#  'university of west georgia',
#  'keio university',
#  'appalachian state university',
#  'peking university',
#  'florida institute of technology',
#  'the open university',
#  'university of helsinki',
#  'wilfrid laurier university',
#  'stockholm environment institute',
#  'university of the philippines diliman',
#  'university of groningen',
#  'charles sturt university',
#  'university of sydney',
#  'duke university',
#  'robert gordon university',
#  'european university institute',
#  'cornell university',
#  'university of reading',
#  'salem college',
#  'cedar crest college',
#  'mid sweden university',
#  'deakin university',
#  'joint research centre',
#  'carnegie mellon university',
#  'canisius college',
#  'university of nicosia',
#  'national and kapodistrian university of athens',
#  'university of modena and reggio emilia',
#  'montclair state university',
#  'university college dublin',
#  'curtin university',
#  'grinnell college',
#  'tata institute of fundamental research',
#  'national taiwan university',
#  'institute of social sciences',
#  'kobe gakuin university',
#  'centre national de la recherche scientifique',
#  'university of antwerp',
#  'university of passau',
#  'ventura college',
#  'california state university los angeles',
#  'marketing science institute',
#  'university of central florida',
#  'whittier college',
#  'university of hohenheim',
#  'mcdaniel college',
#  'kyung hee university',
#  'kent state university',
#  'ewha womans university',
#  'depaul university',
#  'temple university',
#  'macau university of science and technology',
#  'university of rochester',
#  'university of paris',
#  'lehigh university',
#  'albion college',
#  'northern arizona university',
#  'university of sussex',
#  'cancer institute',
#  'ateneo de manila university',
#  'beijing jiaotong university',
#  'northern michigan university',
#  'dakota state university',
#  'university of quebec',
#  'western michigan university',
#  'cleveland state university',
#  'empire state college',
#  'sapir college',
#  'malone university',
#  'university of rhode island',
#  'pacific lutheran university',
#  'lake forest college',
#  'college of management academic studies',
#  'ferrum college',
#  'florida atlantic university',
#  'colorado state university',
#  'saginaw valley state university',
#  'university of warsaw',
#  'clark university',
#  'national university of ireland',
#  'university of minnesota',
#  'rollins college',
#  'bangor university',
#  'university of calgary',
#  'university of leicester',
#  'the university of texas at san antonio',
#  'university of lethbridge',
#  'matsuyama shinonome college',
#  'university of southern mississippi',
#  'wilson college',
#  'institute for infocomm research',
#  'harvard university',
#  'manhattan college',
#  'hamilton college',
#  'salem state university',
#  'university of west florida',
#  'university of northern colorado',
#  'swarthmore college',
#  'tilburg university',
#  'health center',
#  'university of the pacific',
#  'brandeis university',
#  'singapore institute of technology',
#  'university of haifa',
#  'university of central arkansas',
#  'university of the witwatersrand',
#  'yunnan university',
#  'university of south africa',
#  'rider university',
#  'communication university of china',
#  'santa clara university',
#  'technical university of berlin',
#  'uppsala university',
#  'max planck institute for the science of human history',
#  'zeppelin university',
#  'university of bergen',
#  'institute for advanced sustainability studies',
#  'georgian institute of public affairs',
#  'ohio university',
#  'palo alto research center',
#  'clark college',
#  'fisher college',
#  'national center for state courts',
#  'mercy college',
#  'bennington college',
#  'tampere university',
#  'university of chester',
#  'east tennessee state university',
#  'max stern academic college of emek yezreel',
#  'university of montpellier',
#  'university of perugia',
#  'dongguk university',
#  'ie university',
#  'university of san francisco',
#  'northern illinois university',
#  'university of arizona',
#  'wellesley college',
#  'drexel university',
#  'sungkyunkwan university',
#  'kes college',
#  'loughborough university',
#  'university of kansas',
#  'aristotle university of thessaloniki',
#  'centers for disease control and prevention',
#  'campbell college',
#  'university of tsukuba',
#  'phoenix indian medical center',
#  'plymouth state university',
#  'iowa state university',
#  'kyungsung university',
#  'vera institute of justice',
#  'institute of mental health',
#  'university of chicago',
#  'northwestern university',
#  'university of hawaii at manoa',
#  'unity college',
#  'roanoke college',
#  'marist college',
#  'bronx high school of science',
#  'university of florida',
#  'finis terrae university',
#  'hebrew university of jerusalem',
#  'stockholm university',
#  'long island university',
#  'university of southampton',
#  'kirkwood community college',
#  'ruhr university bochum',
#  'audencia business school',
#  'hong kong polytechnic university',
#  'purdue university fort wayne',
#  'institute for advanced study',
#  'coe college',
#  'ege university',
#  'willamette university',
#  'university of new orleans',
#  'university of illinois at chicago',
#  'le moyne college',
#  'university of vienna',
#  'university of bedfordshire',
#  'university of south australia',
#  'university of houston',
#  'university of windsor',
#  'korea university',
#  'old dominion university',
#  'university of memphis',
#  'university of massachusetts amherst',
#  'search institute',
#  'university of baltimore',
#  'osaka university',
#  'state university of new york',
#  'massachusetts institute of technology',
#  'royal institute of technology',
#  'university of ottawa',
#  'athabasca university',
#  'yonsei university',
#  'university of oregon',
#  'diego portales university',
#  'ball state university',
#  'upper iowa university',
#  'university of nottingham',
#  'dean college',
#  'bilkent university',
#  'ces university',
#  'lincoln university',
#  'champlain college',
#  'university of south dakota',
#  'korea information society development institute',
#  'meikai university',
#  'london school of economics and political science',
#  'university of westminster',
#  'insurance institute for highway safety',
#  'beihang university',
#  'wesleyan college',
#  'fairfield university',
#  'american international college',
#  'boston college',
#  'carleton university',
#  'university of graz']

# %%
failed_list = [x for x in affs if x not in matched_dic.keys()]

# %%
failed_list

# %%
len(failed_list)
# Out:
# 2341

# %%
# fuzzy_matched_dic = {}
# for aff in failed_list:
#     match = process.extractOne(aff, ror_affnames, scorer=fuzz.WRatio)[0]
#     fuzzy_matched_dic[aff] = match

# %%
# pd.DataFrame(fuzzy_matched_dic.items()).sample(10)

# %%
failed_list_matched_dic = {}
failed_matched = 0
for aff in failed_list:
    response = requests.get('https://api.ror.org/organizations?query='+aff)
    j = response.json()
    j = j['items'][0]
    try:
        ror_matched_affname = j['name']
        failed_matched += 1
    except:
        ror_matched_affname = None
    failed_list_matched_dic[aff] = ror_matched_affname
    print(f'{failed_list.index(aff) + 1} is done')
# Out:
# 1 is done
# 2 is done
# 3 is done
# 4 is done
# 5 is done
# 6 is done
# 7 is done
# 8 is done
# 9 is done
# 10 is done
# 11 is done
# 12 is done
# 13 is done
# 14 is done
# 15 is done
# 16 is done
# 17 is done
# 18 is done
# 19 is done
# 20 is done
# 21 is done
# 22 is done
# 23 is done
# 24 is done
# 25 is done
# 26 is done
# 27 is done
# 28 is done
# 29 is done
# 30 is done
# 31 is done
# 32 is done
# 33 is done
# 34 is done
# 35 is done
# 36 is done
# 37 is done
# 38 is done
# 39 is done
# 40 is done
# 41 is done
# 42 is done
# 43 is done
# 44 is done
# 45 is done
# 46 is done
# 47 is done
# 48 is done
# 49 is done
# 50 is done
# 51 is done
# 52 is done
# 53 is done
# 54 is done
# 55 is done
# 56 is done
# 57 is done
# 58 is done
# 59 is done
# 60 is done
# 61 is done
# 62 is done
# 63 is done
# 64 is done
# 65 is done
# 66 is done
# 67 is done
# 68 is done
# 69 is done
# 70 is done
# 71 is done
# 72 is done
# 73 is done
# 74 is done
# 75 is done
# 76 is done
# 77 is done
# 78 is done
# 79 is done
# 80 is done
# 81 is done
# 82 is done
# 83 is done
# 84 is done
# 85 is done
# 86 is done
# 87 is done
# 88 is done
# 89 is done
# 90 is done
# 91 is done
# 92 is done
# 93 is done
# 94 is done
# 95 is done
# 96 is done
# 97 is done
# 98 is done
# 99 is done
# 100 is done
# 101 is done
# 102 is done
# 103 is done
# 104 is done
# 105 is done
# 106 is done
# 107 is done
# 108 is done
# 109 is done
# 110 is done
# 111 is done
# 112 is done
# 113 is done
# 114 is done
# 115 is done
# 116 is done
# 117 is done
# 118 is done
# 119 is done
# 120 is done
# 121 is done
# 122 is done
# 123 is done
# 124 is done
# 125 is done
# 126 is done
# 127 is done
# 128 is done
# 129 is done
# 130 is done
# 131 is done
# 132 is done
# 133 is done
# 134 is done
# 135 is done
# 136 is done
# 137 is done
# 138 is done
# 139 is done
# 140 is done
# 141 is done
# 142 is done
# 143 is done
# 144 is done
# 145 is done
# 146 is done
# 147 is done
# 148 is done
# 149 is done
# 150 is done
# 151 is done
# 152 is done
# 153 is done
# 154 is done
# 155 is done
# 156 is done
# 157 is done
# 158 is done
# 159 is done
# 160 is done
# 161 is done
# 162 is done
# 163 is done
# 164 is done
# 165 is done
# 166 is done
# 167 is done
# 168 is done
# 169 is done
# 170 is done
# 171 is done
# 172 is done
# 173 is done
# 174 is done
# 175 is done
# 176 is done
# 177 is done
# 178 is done
# 179 is done
# 180 is done
# 181 is done
# 182 is done
# 183 is done
# 184 is done
# 185 is done
# 186 is done
# 187 is done
# 188 is done
# 189 is done
# 190 is done
# 191 is done
# 192 is done
# 193 is done
# 194 is done
# 195 is done
# 196 is done
# 197 is done
# 198 is done
# 199 is done
# 200 is done
# 201 is done
# 202 is done
# 203 is done
# 204 is done
# 205 is done
# 206 is done
# 207 is done
# 208 is done
# 209 is done
# 210 is done
# 211 is done
# 212 is done
# 213 is done
# 214 is done
# 215 is done
# 216 is done
# 217 is done
# 218 is done
# 219 is done
# 220 is done
# 221 is done
# 222 is done
# 223 is done
# 224 is done
# 225 is done
# 226 is done
# 227 is done
# 228 is done
# 229 is done
# 230 is done
# 231 is done
# 232 is done
# 233 is done
# 234 is done
# 235 is done
# 236 is done
# 237 is done
# 238 is done
# 239 is done
# 240 is done
# 241 is done
# 242 is done
# 243 is done
# 244 is done
# 245 is done
# 246 is done
# 247 is done
# 248 is done
# 249 is done
# 250 is done
# 251 is done
# 252 is done
# 253 is done
# 254 is done
# 255 is done
# 256 is done
# 257 is done
# 258 is done
# 259 is done
# 260 is done
# 261 is done
# 262 is done
# 263 is done
# 264 is done
# 265 is done
# 266 is done
# 267 is done
# 268 is done
# 269 is done
# 270 is done
# 271 is done
# 272 is done
# 273 is done
# 274 is done
# 275 is done
# 276 is done
# 277 is done
# 278 is done
# 279 is done
# 280 is done
# 281 is done
# 282 is done
# 283 is done
# 284 is done
# 285 is done
# 286 is done
# 287 is done
# 288 is done
# 289 is done
# 290 is done
# 291 is done
# 292 is done
# 293 is done
# 294 is done
# 295 is done
# 296 is done
# 297 is done
# 298 is done
# 299 is done
# 300 is done
# 301 is done
# 302 is done
# 303 is done
# 304 is done
# 305 is done
# 306 is done
# 307 is done
# 308 is done
# 309 is done
# 310 is done
# 311 is done
# 312 is done
# 313 is done
# 314 is done
# 315 is done
# 316 is done
# 317 is done
# 318 is done
# 319 is done
# 320 is done
# 321 is done
# 322 is done
# 323 is done
# 324 is done
# 325 is done
# 326 is done
# 327 is done
# 328 is done
# 329 is done
# 330 is done
# 331 is done
# 332 is done
# 333 is done
# 334 is done
# 335 is done
# 336 is done
# 337 is done
# 338 is done
# 339 is done
# 340 is done
# 341 is done
# 342 is done
# 343 is done
# 344 is done
# 345 is done
# 346 is done
# 347 is done
# 348 is done
# 349 is done
# 350 is done
# 351 is done
# 352 is done
# 353 is done
# 354 is done
# 355 is done
# 356 is done
# 357 is done
# 358 is done
# 359 is done
# 360 is done
# 361 is done
# 362 is done
# 363 is done
# 364 is done
# 365 is done
# 366 is done
# 367 is done
# 368 is done
# 369 is done
# 370 is done
# 371 is done
# 372 is done
# 373 is done
# 374 is done
# 375 is done
# 376 is done
# 377 is done
# 378 is done
# 379 is done
# 380 is done
# 381 is done
# 382 is done
# 383 is done
# 384 is done
# 385 is done
# 386 is done
# 387 is done
# 388 is done
# 389 is done
# 390 is done
# 391 is done
# 392 is done
# 393 is done
# 394 is done
# 395 is done
# 396 is done
# 397 is done
# 398 is done
# 399 is done
# 400 is done
# 401 is done
# 402 is done
# 403 is done
# 404 is done
# 405 is done
# 406 is done
# 407 is done
# 408 is done
# 409 is done
# 410 is done
# 411 is done
# 412 is done
# 413 is done
# 414 is done
# 415 is done
# 416 is done
# 417 is done
# 418 is done
# 419 is done
# 420 is done
# 421 is done
# 422 is done
# 423 is done
# 424 is done
# 425 is done
# 426 is done
# 427 is done
# 428 is done
# 429 is done
# 430 is done
# 431 is done
# 432 is done
# 433 is done
# 434 is done
# 435 is done
# 436 is done
# 437 is done
# 438 is done
# 439 is done
# 440 is done
# 441 is done
# 442 is done
# 443 is done
# 444 is done
# 445 is done
# 446 is done
# 447 is done
# 448 is done
# 449 is done
# 450 is done
# 451 is done
# 452 is done
# 453 is done
# 454 is done
# 455 is done
# 456 is done
# 457 is done
# 458 is done
# 459 is done
# 460 is done
# 461 is done
# 462 is done
# 463 is done
# 464 is done
# 465 is done
# 466 is done
# 467 is done
# 468 is done
# 469 is done
# 470 is done
# 471 is done
# 472 is done
# 473 is done
# 474 is done
# 475 is done
# 476 is done
# 477 is done
# 478 is done
# 479 is done
# 480 is done
# 481 is done
# 482 is done
# 483 is done
# 484 is done
# 485 is done
# 486 is done
# 487 is done
# 488 is done
# 489 is done
# 490 is done
# 491 is done
# 492 is done
# 493 is done
# 494 is done
# 495 is done
# 496 is done
# 497 is done
# 498 is done
# 499 is done
# 500 is done
# 501 is done
# 502 is done
# 503 is done
# 504 is done
# 505 is done
# 506 is done
# 507 is done
# 508 is done
# 509 is done
# 510 is done
# 511 is done
# 512 is done
# 513 is done
# 514 is done
# 515 is done
# 516 is done
# 517 is done
# 518 is done
# 519 is done
# 520 is done
# 521 is done
# 522 is done
# 523 is done
# 524 is done
# 525 is done
# 526 is done
# 527 is done
# 528 is done
# 529 is done
# 530 is done
# 531 is done
# 532 is done
# 533 is done
# 534 is done
# 535 is done
# 536 is done
# 537 is done
# 538 is done
# 539 is done
# 540 is done
# 541 is done
# 542 is done
# 543 is done
# 544 is done
# 545 is done
# 546 is done
# 547 is done
# 548 is done
# 549 is done
# 550 is done
# 551 is done
# 552 is done
# 553 is done
# 554 is done
# 555 is done
# 556 is done
# 557 is done
# 558 is done
# 559 is done
# 560 is done
# 561 is done
# 562 is done
# 563 is done
# 564 is done
# 565 is done
# 566 is done
# 567 is done
# 568 is done
# 569 is done
# 570 is done
# 571 is done
# 572 is done
# 573 is done
# 574 is done
# 575 is done
# 576 is done
# 577 is done
# 578 is done
# 579 is done
# 580 is done
# 581 is done
# 582 is done
# 583 is done
# 584 is done
# 585 is done
# 586 is done
# 587 is done
# 588 is done
# 589 is done
# 590 is done
# 591 is done
# 592 is done
# 593 is done
# 594 is done
# 595 is done
# 596 is done
# 597 is done
# 598 is done
# 599 is done
# 600 is done
# 601 is done
# 602 is done
# 603 is done
# 604 is done
# 605 is done
# 606 is done
# 607 is done
# 608 is done
# 609 is done
# 610 is done
# 611 is done
# 612 is done
# 613 is done
# 614 is done
# 615 is done
# 616 is done
# 617 is done
# 618 is done
# 619 is done
# 620 is done
# 621 is done
# 622 is done
# 623 is done
# 624 is done
# 625 is done
# 626 is done
# 627 is done
# 628 is done
# 629 is done
# 630 is done
# 631 is done
# 632 is done
# 633 is done
# 634 is done
# 635 is done
# 636 is done
# 637 is done
# 638 is done
# 639 is done
# 640 is done
# 641 is done
# 642 is done
# 643 is done
# 644 is done
# 645 is done
# 646 is done
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [95], in <cell line: 3>()
#       4 response = requests.get('https://api.ror.org/organizations?query='+aff)
#       5 j = response.json()
# ----> 6 j = j['items'][0]
#       7 try:
#       8     ror_matched_affname = j['name']
#
# IndexError: list index out of range

# %%
pd.DataFrame(failed_list_matched_dic.items()).sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0  \
# 342                                                                                                                                                                                                                                                                                                                                                                                 dr maclay is a research associate professor in the institute of communications research at the university of illinois
# 607                                                                                                                                                                                                                                                                                                                                                                                                                                    department of communications university of california davis ca usa
# 106                                                                                                                                                                                                                                                                                                                                                a doctoral student in the department of communication at texas a amp m university her research interests include political and organizational rhetoric
# 119                                                                                                                                                                                                                                                                                                                                                                                                                  department of communication science vu university amsterdam amsterdam hv netherlands
# 553                                                                                                                                                                                                                                                                                                                                                                                                                                     communication studies university of texas at austin austin tx usa
# 619                                                                                                                                                                                                                                                                                                                                                                                                                             b s rutgers university is business development manager at doubleclick inc
# 374                                                                                                                                                                                                                                                                                                                                                                                                     department of journalism and communication research hanover university of music and drama germany
# 164                                                                                                                                                                                                                                                                                                                                                                               department of life sciences communication university of wisconsin madison hiram smith hall observatory drive madison wi
# 452  graduate student in the media lab s sociable media group her current work focuses on developing interfaces that examine the interaction of people and the social cues they perceive in networked electronic spaces previous work has included browsing large video banks as well as reconstructing three dimensional spaces from multiple media sources she holds an sb in electrical engineering an me in electrical engineering and computer science and an sm in media arts and sciences from mit
# 184                                                                                                                                                                                                                                                                                                                                                                                                                              department of computer science stoneybrook university stoneybrook ny usa
#
#                                                                     1
# 342                                 Karlsruhe Institute of Technology
# 607                                   University of California, Davis
# 106                                     Texas A&M University at Qatar
# 119                                      Vrije Universiteit Amsterdam
# 553                                 The University of Texas at Austin
# 619                       Rutgers, The State University of New Jersey
# 374                       Hanover University of Music Drama and Media
# 164                                   University of Wisconsin–Madison
# 452  Beijing Jingshida Electromechanical Equipment Research Institute
# 184                                       Computer Science Department

# %%
a_dic = {}
