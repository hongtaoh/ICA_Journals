# %% [markdown]
# ## AIM
#
# In this notebook, I processed the affiliation data. I have the coded results, now I need to fill in data using the dict from ror dataset and I also need to check whether there is any error in the coded data.
#
# Later, codes here became part of `get_authorid_with_vars.py`

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
ror_raw = '../../data/raw/large/ror.json'

# %%
df1 = pd.read_csv('../../data/interim/aff_result/hongtao.csv')
df1.head()
# Out:
#    Unnamed: 0                  authorID                   doi  \
# 0        8674  10.1093/jcmc/zmab019+4.0  10.1093/jcmc/zmab019
# 1        8675  10.1093/jcmc/zmab019+5.0  10.1093/jcmc/zmab019
# 2          26   10.1093/joc/jqab052+5.0   10.1093/joc/jqab052
# 3       10667   10.1093/ccc/tcac007+1.0   10.1093/ccc/tcac007
# 4          14   10.1093/joc/jqac012+4.0   10.1093/joc/jqac012
#
#                                                           url  year  \
# 0  https://academic.oup.com/jcmc/article/27/1/zmab019/6427305  2022
# 1  https://academic.oup.com/jcmc/article/27/1/zmab019/6427305  2022
# 2       https://academic.oup.com/joc/article/72/2/187/6506191  2022
# 3       https://academic.oup.com/ccc/article/15/2/157/6570646  2022
# 4       https://academic.oup.com/joc/article/72/3/429/6573231  2022
#
#                                                                                                                                   title  \
# 0                                 Beyond Anonymity: Network Affordances, Under Deindividuation, Improve Social Media Discussion Quality
# 1                                 Beyond Anonymity: Network Affordances, Under Deindividuation, Improve Social Media Discussion Quality
# 2   The Effects of Tobacco Coverage in the Public Communication Environment on Young People’s Decisions to Smoke Combustible Cigarettes
# 3                            Digitalization, Digitization and Datafication: The "Three D" Transformation of Forced Migration Management
# 4  To Misspecify Is Common, to Probe Misspecification Scientific: Common “Confounds” in Pornography Research May Actually Be Predictors
#
#                                       journal  numberOfAuthors  \
# 0  Journal of Computer-Mediated Communication                5
# 1  Journal of Computer-Mediated Communication                5
# 2                    Journal of Communication               18
# 3         Communication, Culture and Critique                1
# 4                    Journal of Communication                4
#
#    authorPosition    authorFullName firstName   lastName  \
# 0               4    Jana Egelhofer      Jana  Egelhofer
# 1               5   Sophie Lecheler    Sophie   Lecheler
# 2               5    Michelle Jeong  Michelle      Jeong
# 3               1  Saskia Witteborn    Saskia  Witteborn
# 4               4       Bryant Paul    Bryant       Paul
#
#                                                                                                                                                                                                                    affiliation  \
# 0                                                                                                                                                         Department of Communication, University of Vienna , Vienna,  Austria
# 1                                                                                                                                                         Department of Communication, University of Vienna , Vienna,  Austria
# 2  Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA    Department of Health Behavior, Society and Policy, Rutgers University School of Public Health , Piscataway, NJ 08854,  USA
# 3                                                                                                                   The Chinese University of Hong Kong, School of Journalism and Communication, CUHK, Shatin, N.T., Hong Kong
# 4                                                                                                                                     Communication Science Unit, The Media School, Indiana University , Bloomington, IN,  USA
#
#                                                                   gscholarLink  \
# 0    https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Jana+Egelhofer
# 1   https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Sophie+Lecheler
# 2    https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Michelle+Jeong
# 3  https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Saskia+Witteborn
# 4       https://scholar.google.com/scholar?hl=en&as_sdt=0%252C50&q=Bryant+Paul
#
#                                                                                                                                                                                                                                      googleSearch  \
# 0                                                                                                                                  https://www.google.com/search?q=Jana+Egelhofer+department+of+communication+university+of+vienna+vienna+austria
# 1                                                                                                                                 https://www.google.com/search?q=Sophie+Lecheler+department+of+communication+university+of+vienna+vienna+austria
# 2  https://www.google.com/search?q=Michelle+Jeong+annenberg+school+for+communication+university+of+pennsylvania+philadelphia+pa+usa+department+of+health+behavior+society+and+policy+rutgers+university+school+of+public+health+piscataway+nj+usa
# 3                                                                                           https://www.google.com/search?q=Saskia+Witteborn+the+chinese+university+of+hong+kong+school+of+journalism+and+communication+cuhk+shatin+n+t+hong+kong
# 4                                                                                                                   https://www.google.com/search?q=Bryant+Paul+communication+science+unit+the+media+school+indiana+university+bloomington+in+usa
#
#                                                                                                                                                                                       affProcessed  \
# 0                                                                                                                                  department of communication university of vienna vienna austria
# 1                                                                                                                                  department of communication university of vienna vienna austria
# 2  annenberg school for communication university of pennsylvania philadelphia pa usa department of health behavior society and policy rutgers university school of public health piscataway nj usa
# 3                                                                                             the chinese university of hong kong school of journalism and communication cuhk shatin n t hong kong
# 4                                                                                                                communication science unit the media school indiana university bloomington in usa
#
#                                                                                                                                                                                                                  affiliation.2  \
# 0                                                                                                                                                         Department of Communication, University of Vienna , Vienna,  Austria
# 1                                                                                                                                                         Department of Communication, University of Vienna , Vienna,  Austria
# 2  Annenberg School for Communication, University of Pennsylvania , Philadelphia, PA 19104,  USA    Department of Health Behavior, Society and Policy, Rutgers University School of Public Health , Piscataway, NJ 08854,  USA
# 3                                                                                                                   The Chinese University of Hong Kong, School of Journalism and Communication, CUHK, Shatin, N.T., Hong Kong
# 4                                                                                                                                     Communication Science Unit, The Media School, Indiana University , Bloomington, IN,  USA
#
#                        ROR_AFFNAME matchMethod aff_prediction country_code  \
# 0             University of Vienna       Exact            NaN          NaN
# 1             University of Vienna       Exact            NaN          NaN
# 2       University of Pennsylvania       Exact            NaN          NaN
# 3  Chinese University of Hong Kong       Exact            NaN          NaN
# 4   Indiana University Bloomington       Exact            NaN          NaN
#
#   aff_type                     ROR_ID
# 0      NaN  https://ror.org/03prydq77
# 1      NaN  https://ror.org/03prydq77
# 2      NaN  https://ror.org/00b30xv10
# 3      NaN  https://ror.org/00t33hh48
# 4      NaN  https://ror.org/02k40bc56

# %%
df1 = df1[df1.year >= 2000][['authorID', 'country_code', 'aff_type', 'ROR_ID']]
# set(df1.aff_type), set(df1.country_code)

# %%
df1[df1.ROR_ID.isnull()]
# Out:
#                                     authorID country_code aff_type ROR_ID
# 4121                 10.1093/jcmc/zmz031+1.0           CH        1    NaN
# 4127                 10.1093/jcmc/zmz031+3.0           CH        1    NaN
# 4162                  10.1093/ccc/tcz025+4.0           CR        1    NaN
# 4167                  10.1093/ccc/tcz025+2.0           CR        1    NaN
# 4180                  10.1093/joc/jqy030+2.0           CH        1    NaN
# 4195                  10.1093/joc/jqy030+3.0           CH        1    NaN
# 4460    10.1111/j.1753-9137.2012.01124.x+3.0           CH        1    NaN
# 4846  10.1111/j.1083-6101.2003.tb00220.x+2.0           US        1    NaN
# 4881  10.1111/j.1083-6101.2002.tb00157.x+1.0           US        1    NaN
# 5651  10.1111/j.1468-2958.2001.tb00779.x+1.0           US        1    NaN

# %%
pd.isnull(df1.iloc[0, :]['country_code'])
# Out:
# True

# %%
df1[df1.country_code == 'CZ']
# Out:
# Empty DataFrame
# Columns: [authorID, country_code, aff_type, ROR_ID]
# Index: []

# %%
df2 = pd.read_csv('../../data/interim/aff_result/kristen.csv')
df2 = df2[df2.year >= 2000][['authorID', 'country_code', 'aff_type', 'ROR_ID']]
# set(df2.aff_type), set(df2.country_code)

# %%
df2[df2.country_code == 'CZ']
# Out:
#                                   authorID country_code aff_type  \
# 4722  10.1111/j.1460-2466.2007.00360.x+3.0           CZ        0
# 4731  10.1111/j.1468-2958.2007.00308.x+3.0           CZ        0
#
#                          ROR_ID
# 4722  https://ror.org/0542dkz21
# 4731  https://ror.org/0542dkz21

# %%
df2[df2.ROR_ID.isnull()]
# Out:
#                                     authorID country_code aff_type ROR_ID
# 4066                 10.1093/jcmc/zmz031+2.0           CH        1    NaN
# 4108                  10.1093/ccc/tcz025+1.0           CR        1    NaN
# 4142                  10.1093/ccc/tcz025+3.0           CR        1    NaN
# 4192                  10.1093/joc/jqy030+1.0           CH        1    NaN
# 4247                  10.1111/hcre.12125+1.0           US        1    NaN
# 4468    10.1111/j.1753-9137.2012.01124.x+2.0           CH        1    NaN
# 4808  10.1111/j.1468-2958.2005.tb00874.x+3.0           US        0    NaN
# 4993  10.1111/j.1083-6101.2000.tb00347.x+2.0           CH        0    NaN
# 4999  10.1111/j.1083-6101.2000.tb00113.x+6.0           UK        0    NaN
# 5651  10.1111/j.1468-2958.2001.tb00781.x+5.0           US        1    NaN

# %%
def load_ror_dataset(ROR_RAW_DATA):
    '''read in ROR_DATA
    Output:
        a list of dictionaries
    '''
    with open(ROR_RAW_DATA, 'r') as myfile:
        data=myfile.read()
    data = json.loads(data)
    return data

# %%
ror = load_ror_dataset(ror_raw)

# %%
'''this is to build two dictionaries based on ror raw data
'''
ror_cntry_dic = {}
ror_afftype_dic = {}
for i in ror:
    ror_id = i['id']
    cntry = i['country']['country_code']
    try:
        afftype = i['types'][0]
        if afftype == 'Education':
            afftype = afftype
        else:
            afftype = 'Non Education'
    except:
        afftype = None
    ror_cntry_dic[ror_id] = cntry
    ror_afftype_dic[ror_id] = afftype

# %%
def get_new_cntry_code(row):
    if pd.isnull(row['country_code']):
        new_country_code = ror_cntry_dic[row['ROR_ID']]
    else:
        new_country_code = row['country_code']
    return new_country_code

# %%
def get_new_afftype(row):
    if pd.isnull(row['aff_type']):
        new_afftype = ror_afftype_dic[row['ROR_ID']]
    elif row['aff_type'] == '1':
        new_afftype = 'Education'
    elif row['aff_type'] == '0':
        new_afftype = 'Non Education'
    return new_afftype

# %%
df1['new_country_code'] = df1.apply(get_new_cntry_code, axis = 1)
df1['new_afftype'] = df1.apply(get_new_afftype, axis = 1)
df2['new_country_code'] = df2.apply(get_new_cntry_code, axis = 1)
df2['new_afftype'] = df2.apply(get_new_afftype, axis = 1)

# %%
df = pd.concat([df1, df2], ignore_index = True)
df.head()
# Out:
#                    authorID country_code aff_type                     ROR_ID  \
# 0  10.1093/jcmc/zmab019+4.0          NaN      NaN  https://ror.org/03prydq77
# 1  10.1093/jcmc/zmab019+5.0          NaN      NaN  https://ror.org/03prydq77
# 2   10.1093/joc/jqab052+5.0          NaN      NaN  https://ror.org/00b30xv10
# 3   10.1093/ccc/tcac007+1.0          NaN      NaN  https://ror.org/00t33hh48
# 4   10.1093/joc/jqac012+4.0          NaN      NaN  https://ror.org/02k40bc56
#
#   new_country_code new_afftype
# 0               AT   Education
# 1               AT   Education
# 2               US   Education
# 3               CN   Education
# 4               US   Education

# %%
f, ax = plt.subplots(figsize=(12,6))
ax.set(yscale = 'log')
sns.countplot(x = 'new_country_code', data = df, ax = ax)
# Out:
# <AxesSubplot:xlabel='new_country_code', ylabel='count'>

# %%
f, ax = plt.subplots(figsize=(7, 7))
# ax.set(yscale='log')
sns.countplot(x = 'new_afftype', data = df, ax = ax)
# Out:
# <AxesSubplot:xlabel='new_afftype', ylabel='count'>

# %%
df.shape
# Out:
# (4434, 6)

# %%
df.to_csv('aff_df.csv', index = False)
