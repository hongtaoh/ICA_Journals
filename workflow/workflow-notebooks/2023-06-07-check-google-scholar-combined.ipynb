# %% [markdown]
# The aim of this notebook is to check whether the combined dataset looks good.

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/gscholar_data_combined.csv')

# %%
df.shape
# Out:
# (5719, 6)

# %%
df.loc[df.DOI == '10.1111/j.1460-2466.1977.tb02133.x']
# Out:
#                Original Title Title on Google Scholar  \
# 1904  “Beneficial” Aggression   Marital Communication
#
#                                      DOI    Year  \
# 1904  10.1111/j.1460-2466.1977.tb02133.x  1977.0
#
#                                           Citation Link  \
# 1904  https://scholar.google.com/scholar?cites=10720...
#
#       Citation Counts on Google Scholar
# 1904                                  8

# %%
df.loc[df.DOI == '10.1111/j.1083-6101.1996.tb00178.x']
# Out:
#                                          Original Title  \
# 5718  Cyberspaces: Familiar territory or lawless fro...
#
#                                 Title on Google Scholar  \
# 5718  Cyberspaces: Familiar territory or lawless fro...
#
#                                      DOI  Year  \
# 5718  10.1111/j.1083-6101.1996.tb00178.x   NaN
#
#                                           Citation Link  \
# 5718  https://onlinelibrary.wiley.com/doi/abs/10.111...
#
#       Citation Counts on Google Scholar
# 5718                                 24

# %%
df.loc[df.DOI == '10.1111/j.1460-2466.1952.tb00171.x']
# Out:
#            Original Title                   Title on Google Scholar  \
# 2531  Communications 1952  [CITATION] Communication Courses in 1952
#
#                                      DOI    Year  \
# 2531  10.1111/j.1460-2466.1952.tb00171.x  1952.0
#
#                                           Citation Link  \
# 2531  https://scholar.google.com/scholar?q=related:i...
#
#       Citation Counts on Google Scholar
# 2531                                  0

# %%
df.loc[~df.DOI.isin(['10.1111/j.1460-2466.1952.tb00171.x', '10.1111/j.1460-2466.1977.tb02133.x'])]
# Out:
#                                          Original Title  \
# 0     The Gender Divide in Wikipedia: Quantifying an...
# 1     Mapping Exposure Diversity: The Divergent Effe...
# 2     Democratic Consequences of Incidental Exposure...
# 3     The Great and Powerful Dr. Oz? Alternative Hea...
# 4     A Methodological Framework for Analyzing the A...
# ...                                                 ...
# 5714  Remaking the #Syllabus: Crowdsourcing Resistan...
# 5715  #ThisEndsHere: Confronting Sexual Assault and ...
# 5716  Toxic Identification: #Twinks4Trump and the Ho...
# 5717  #nolitetebastardescarborundorum: Self-Publishi...
# 5718  Cyberspaces: Familiar territory or lawless fro...
#
#                                 Title on Google Scholar  \
# 0     The Gender Divide in Wikipedia: Quantifying an...
# 1     Mapping exposure diversity: The divergent effe...
# 2     Democratic consequences of incidental exposure...
# 3     The great and powerful Dr. Oz? Alternative hea...
# ...
